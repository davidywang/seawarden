# %%
#aerialImageRetrieval commandline in python
#%run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping
from aerialImageRetrieval import AerialImageRetrieval

#select country
n = 'ESP'

#load csv containing coordinates of polygon corners
f = '../targets_1_bing/'
file = f + 'sar_' + n + '.csv'
#file = f + '2019_g25_100m_10-20_1yr_02-01.csv'
targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))

tl = targets.drop(targets.index[0])
tl = tl.iloc[::5]
print(len(tl))

br = targets.drop(targets.index[0:3])
br = br.iloc[::5] 
print(len(br))

# create lists
lat1_list=tl['y'].tolist()
lon1_list=tl['x'].tolist()
lat2_list=br['y'].tolist()
lon2_list=br['x'].tolist()
# Out:
# 13235
# 2647
# 2647

# %%
#for i in range(0,1000): #do 1000 at a time
for i in range(1855, 3000):
    lat1=round(lat1_list[i],5)
    lon1=round(lon1_list[i],5)
    lat2=round(lat2_list[i],5)
    lon2=round(lon2_list[i],5)
    
#     xy = mapping(centroids.geometry[i])['coordinates']
#     x = round(xy[0], 5)
#     y = round(xy[1], 5)

    #imgretrieval = AerialImageRetrieval(x, y, lat1, lon1, lat2, lon2)
    imgretrieval = AerialImageRetrieval(lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print("Retrieved image:", lat1, lon1, lat2, lon2)
    else:
        print("Cannot retrieve image:", lat1, lon1, lat2, lon2)
# Out:
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.83161 3.13543 39.84129 3.12466
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.85061 2.80937 39.86026 2.79855
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.85004 3.10714 39.85972 3.09636
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99295 0.0171 40.00234 0.00587
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99035 0.02136 39.99974 0.01013
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.85038 3.10649 39.86005 3.09571
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131098, 99247)
# *Cannot find tile image at level 17 for tile coordinate (65549, 49624)
# Retrieved image: 39.99314 0.03574 40.00252 0.02451
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134527, 99474)
# *Cannot find tile image at level 17 for tile coordinate (67263, 49737)
# *Cannot find tile image at level 16 for tile coordinate (33631, 24868)
# *Cannot find tile image at level 15 for tile coordinate (16815, 12434)
# *Cannot find tile image at level 14 for tile coordinate (8407, 6217)
# Retrieved image: 39.74509 4.75528 39.75492 4.74476
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99456 0.01206 40.00394 0.00083
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99478 0.0199 40.00416 0.00868
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99595 0.0107 40.00534 -0.00053
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99597 0.03673 40.00536 0.02551
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.9963 0.03225 40.00569 0.02102
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99672 0.02023 40.0061 0.00901
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.8565 3.1169 39.86618 3.10612
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131100, 99236)
# *Cannot find tile image at level 17 for tile coordinate (65550, 49618)
# Retrieved image: 39.99715 0.03846 40.00654 0.02724
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99895 0.0263 40.00834 0.01508
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99964 0.02163 40.00902 0.0104
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.8592 3.12433 39.86888 3.11355
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133402, 99370)
# *Cannot find tile image at level 17 for tile coordinate (66702, 49685)
# Retrieved image: 39.85537 3.20296 39.86505 3.1922
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.85866 3.19328 39.86835 3.18251
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.00488 0.03417 40.01426 0.02294
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133028, 99338)
# *Cannot find tile image at level 17 for tile coordinate (66514, 49669)
# *Cannot find tile image at level 16 for tile coordinate (33257, 24834)
# *Cannot find tile image at level 15 for tile coordinate (16628, 12417)
# *Cannot find tile image at level 14 for tile coordinate (8314, 6208)
# Retrieved image: 39.88903 2.69747 39.89867 2.68663
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131102, 99229)
# *Cannot find tile image at level 17 for tile coordinate (65551, 49615)
# Retrieved image: 40.00678 0.04244 40.01617 0.03121
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133357, 99364)
# Retrieved image: 39.86204 3.14895 39.87172 3.13818
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.85946 3.19316 39.86914 3.18239
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.86381 3.19212 39.87349 3.18136
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.00905 0.03535 40.01844 0.02412
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131104, 99224)
# *Cannot find tile image at level 17 for tile coordinate (65552, 49613)
# Retrieved image: 40.0095 0.04493 40.01889 0.03371
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.866 3.19074 39.87569 3.17997
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.01191 0.01319 40.0213 0.00195
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134186, 99427)
# *Cannot find tile image at level 17 for tile coordinate (67093, 49714)
# Retrieved image: 39.79654 4.28757 39.80633 4.27697
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133370, 99357)
# *Cannot find tile image at level 17 for tile coordinate (66685, 49678)
# Retrieved image: 39.8688 3.16739 39.87848 3.15662
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131106, 99221)
# *Cannot find tile image at level 17 for tile coordinate (65553, 49610)
# Retrieved image: 40.01194 0.04746 40.02133 0.03624
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.01439 0.0123 40.02377 0.00107
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.79833 4.29409 39.80811 4.28349
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134201, 99424)
# *Cannot find tile image at level 17 for tile coordinate (67101, 49712)
# Retrieved image: 39.79803 4.30068 39.80781 4.29009
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.01473 0.02782 40.02412 0.01659
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.87102 3.19302 39.88071 3.18226
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.01595 0.03244 40.02533 0.02122
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133398, 99360)
# *Cannot find tile image at level 17 for tile coordinate (66699, 49680)
# Retrieved image: 39.86938 3.19449 39.87906 3.18372
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.87165 3.19394 39.88133 3.18318
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133398, 99360)
# *Cannot find tile image at level 17 for tile coordinate (66699, 49680)
# Retrieved image: 39.87259 3.19531 39.88228 3.18455
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134164, 99421)
# *Cannot find tile image at level 17 for tile coordinate (67082, 49711)
# Retrieved image: 39.8051 4.25786 39.81488 4.24725
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.0184 0.03866 40.02779 0.02744
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131104, 99224)
# Retrieved image: 40.01867 0.04415 40.02805 0.03292
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.0195 0.03606 40.02888 0.02483
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133185, 99336)
# *Cannot find tile image at level 17 for tile coordinate (66592, 49668)
# Retrieved image: 39.89152 2.91377 39.90117 2.90297
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134156, 99419)
# *Cannot find tile image at level 17 for tile coordinate (67078, 49710)
# Retrieved image: 39.80811 4.24702 39.81789 4.23641
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133190, 99335)
# *Cannot find tile image at level 17 for tile coordinate (66595, 49667)
# Retrieved image: 39.89248 2.92046 39.90214 2.90965
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88714 3.08625 39.89682 3.07547
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133194, 99330)
# *Cannot find tile image at level 17 for tile coordinate (66597, 49665)
# Retrieved image: 39.89752 2.92604 39.90718 2.91523
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133196, 99331)
# *Cannot find tile image at level 17 for tile coordinate (66598, 49665)
# Retrieved image: 39.89635 2.9286 39.90601 2.91779
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134141, 99411)
# *Cannot find tile image at level 17 for tile coordinate (67070, 49706)
# Retrieved image: 39.81792 4.22655 39.8277 4.21594
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131112, 99208)
# *Cannot find tile image at level 17 for tile coordinate (65556, 49604)
# Retrieved image: 40.02964 0.05556 40.03903 0.04433
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134891, 99474)
# *Cannot find tile image at level 17 for tile coordinate (67445, 49737)
# *Cannot find tile image at level 16 for tile coordinate (33722, 24868)
# *Cannot find tile image at level 15 for tile coordinate (16861, 12434)
# *Cannot find tile image at level 14 for tile coordinate (8430, 6217)
# Retrieved image: 39.74506 5.25525 39.75494 5.2448
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133398, 99341)
# *Cannot find tile image at level 17 for tile coordinate (66699, 49670)
# Retrieved image: 39.88613 3.20547 39.89581 3.1947
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134137, 99409)
# *Cannot find tile image at level 17 for tile coordinate (67068, 49705)
# Retrieved image: 39.82162 4.21979 39.8314 4.20918
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131114, 99206)
# *Cannot find tile image at level 17 for tile coordinate (65556, 49604)
# Retrieved image: 40.03177 0.05808 40.04116 0.04686
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131116, 99205)
# *Cannot find tile image at level 17 for tile coordinate (65558, 49603)
# Retrieved image: 40.03343 0.06129 40.04282 0.05006
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.89626 3.08941 39.90594 3.07862
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.89723 3.08704 39.90691 3.07626
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131119, 99203)
# *Cannot find tile image at level 17 for tile coordinate (65559, 49602)
# Retrieved image: 40.03512 0.06457 40.04451 0.05334
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131120, 99202)
# *Cannot find tile image at level 17 for tile coordinate (65559, 49602)
# Retrieved image: 40.0366 0.06766 40.04598 0.05643
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90111 3.09596 39.91079 3.08517
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90166 3.09672 39.91133 3.08593
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90015 3.09602 39.90982 3.08523
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90009 3.09778 39.90977 3.08699
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90232 3.0943 39.912 3.08351
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90178 3.10678 39.91146 3.096
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90219 3.10521 39.91187 3.09442
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90295 3.09596 39.91263 3.08517
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131124, 99200)
# *Cannot find tile image at level 17 for tile coordinate (65562, 49600)
# Retrieved image: 40.04071 0.0733 40.0501 0.06208
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90212 3.10047 39.9118 3.08968
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.9025 3.09564 39.91218 3.08486
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.9017 3.10108 39.91137 3.09029
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90203 3.09773 39.91171 3.08695
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.9034 3.09645 39.91308 3.08567
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90353 3.10482 39.91321 3.09404
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90304 3.10108 39.91272 3.09029
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90333 3.09807 39.91301 3.08728
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131128, 99197)
# *Cannot find tile image at level 17 for tile coordinate (65564, 49599)
# Retrieved image: 40.04169 0.07749 40.05108 0.06626
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90448 3.09533 39.91416 3.08454
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90412 3.09492 39.9138 3.08414
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133218, 99314)
# *Cannot find tile image at level 17 for tile coordinate (66609, 49657)
# Retrieved image: 39.91385 2.9584 39.92351 2.94759
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134108, 99390)
# *Cannot find tile image at level 17 for tile coordinate (67054, 49696)
# Retrieved image: 39.83838 4.18003 39.84816 4.16941
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131132, 99193)
# *Cannot find tile image at level 17 for tile coordinate (65566, 49597)
# Retrieved image: 40.04703 0.08366 40.05642 0.07243
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131135, 99191)
# *Cannot find tile image at level 17 for tile coordinate (65567, 49596)
# Retrieved image: 40.04905 0.08654 40.05844 0.07532
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131135, 99191)
# *Cannot find tile image at level 17 for tile coordinate (65567, 49596)
# Retrieved image: 40.05043 0.08893 40.05982 0.07771
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134103, 99386)
# *Cannot find tile image at level 17 for tile coordinate (67051, 49693)
# Retrieved image: 39.8457 4.17347 39.85548 4.16285
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131139, 99191)
# *Cannot find tile image at level 17 for tile coordinate (65569, 49596)
# Retrieved image: 40.05094 0.10324 40.06033 0.09202
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131136, 99191)
# *Cannot find tile image at level 17 for tile coordinate (65568, 49596)
# Retrieved image: 40.05108 0.09914 40.06047 0.08792
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.89962 3.09114 39.90929 3.08036
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.89972 3.09057 39.90939 3.07978
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134204, 99410)
# *Cannot find tile image at level 17 for tile coordinate (67102, 49705)
# Retrieved image: 39.82228 4.30122 39.83207 4.29062
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134096, 99380)
# *Cannot find tile image at level 17 for tile coordinate (67048, 49691)
# Retrieved image: 39.84812 4.16431 39.85789 4.15369
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133258, 99307)
# *Cannot find tile image at level 17 for tile coordinate (66629, 49653)
# Retrieved image: 39.92132 3.01302 39.93099 3.00222
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.92706 3.05246 39.93674 3.04166
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133272, 99299)
# *Cannot find tile image at level 17 for tile coordinate (66636, 49649)
# Retrieved image: 39.92986 3.03334 39.93953 3.02255
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134077, 99370)
# *Cannot find tile image at level 17 for tile coordinate (67038, 49685)
# Retrieved image: 39.86433 4.13775 39.87411 4.12712
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133321, 99299)
# *Cannot find tile image at level 17 for tile coordinate (66660, 49649)
# Retrieved image: 39.93028 3.10061 39.93996 3.08982
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133338, 99299)
# *Cannot find tile image at level 17 for tile coordinate (66669, 49649)
# Retrieved image: 39.92991 3.12347 39.93959 3.11268
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (135255, 99474)
# *Cannot find tile image at level 17 for tile coordinate (67627, 49737)
# *Cannot find tile image at level 16 for tile coordinate (33813, 24868)
# *Cannot find tile image at level 15 for tile coordinate (16906, 12434)
# *Cannot find tile image at level 14 for tile coordinate (8453, 6217)
# Retrieved image: 39.74504 5.75522 39.75496 5.74484
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131173, 99170)
# *Cannot find tile image at level 17 for tile coordinate (65587, 49585)
# Retrieved image: 40.07093 0.14038 40.08033 0.12916
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133394, 99302)
# *Cannot find tile image at level 17 for tile coordinate (66697, 49651)
# Retrieved image: 39.93299 3.18884 39.94268 3.17806
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134050, 99355)
# *Cannot find tile image at level 17 for tile coordinate (67025, 49678)
# Retrieved image: 39.87665 4.10058 39.88642 4.08994
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133408, 99294)
# *Cannot find tile image at level 17 for tile coordinate (66704, 49647)
# Retrieved image: 39.93946 3.20905 39.94915 3.19827
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.8734 4.31297 39.88319 4.30236
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134223, 99354)
# *Cannot find tile image at level 17 for tile coordinate (67113, 49677)
# Retrieved image: 39.87236 4.33308 39.88215 4.32247
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134217, 99350)
# Retrieved image: 39.87594 4.31951 39.88573 4.3089
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133363, 99279)
# *Cannot find tile image at level 17 for tile coordinate (66681, 49639)
# Retrieved image: 39.95094 3.15715 39.96062 3.14637
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.87719 4.30387 39.88698 4.29326
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133415, 99283)
# *Cannot find tile image at level 17 for tile coordinate (66707, 49643)
# Retrieved image: 39.94921 3.21862 39.9589 3.20784
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133366, 99278)
# *Cannot find tile image at level 17 for tile coordinate (66683, 49639)
# Retrieved image: 39.95268 3.16164 39.96236 3.15085
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133403, 99280)
# Retrieved image: 39.95056 3.20293 39.96025 3.19215
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.09282 0.1495 40.10222 0.13827
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134023, 99332)
# *Cannot find tile image at level 17 for tile coordinate (67011, 49667)
# Retrieved image: 39.8974 4.06395 39.90717 4.0533
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134215, 99346)
# Retrieved image: 39.88076 4.31709 39.89055 4.30649
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133399, 99278)
# *Cannot find tile image at level 17 for tile coordinate (66699, 49639)
# Retrieved image: 39.95252 3.20709 39.96221 3.19632
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.8827 4.29071 39.89249 4.2801
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88354 4.28222 39.89333 4.2716
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133377, 99275)
# *Cannot find tile image at level 17 for tile coordinate (66688, 49637)
# Retrieved image: 39.95512 3.17716 39.9648 3.16638
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131183, 99149)
# Retrieved image: 40.09586 0.153 40.10526 0.14177
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133408, 99276)
# *Cannot find tile image at level 17 for tile coordinate (66708, 49638)
# Retrieved image: 39.95381 3.21963 39.9635 3.20885
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88415 4.30071 39.89394 4.2901
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134214, 99343)
# *Cannot find tile image at level 17 for tile coordinate (67107, 49671)
# Retrieved image: 39.88365 4.31657 39.89344 4.30596
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133382, 99273)
# *Cannot find tile image at level 17 for tile coordinate (66691, 49636)
# Retrieved image: 39.95695 3.1831 39.96663 3.17232
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88778 4.27785 39.89756 4.26724
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133409, 99274)
# *Cannot find tile image at level 17 for tile coordinate (66704, 49637)
# Retrieved image: 39.95586 3.22068 39.96555 3.20991
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88816 4.27342 39.89795 4.2628
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88789 4.28427 39.89768 4.27366
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.88928 4.26437 39.89906 4.25376
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134213, 99340)
# Retrieved image: 39.88638 4.31426 39.89617 4.30365
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133894, 99318)
# *Cannot find tile image at level 17 for tile coordinate (66947, 49659)
# Retrieved image: 39.91734 3.88633 39.92709 3.87565
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (135545, 99471)
# *Cannot find tile image at level 17 for tile coordinate (67772, 49735)
# *Cannot find tile image at level 16 for tile coordinate (33886, 24867)
# *Cannot find tile image at level 15 for tile coordinate (16943, 12433)
# *Cannot find tile image at level 14 for tile coordinate (8471, 6216)
# Retrieved image: 39.74833 6.15316 39.75829 6.14283
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134002, 99321)
# *Cannot find tile image at level 17 for tile coordinate (67001, 49661)
# Retrieved image: 39.91147 4.03553 39.92123 4.02488
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.89309 4.31154 39.90288 4.30093
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.89977 4.30171 39.90956 4.29109
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133384, 99275)
# *Cannot find tile image at level 17 for tile coordinate (66692, 49637)
# Retrieved image: 39.9555 3.18633 39.96518 3.17555
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90018 4.30061 39.90997 4.29
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90203 4.29992 39.91182 4.28931
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90323 4.30125 39.91302 4.29064
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90387 4.29943 39.91365 4.28882
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90573 4.29815 39.91552 4.28753
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90706 4.2968 39.91685 4.28618
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90733 4.29536 39.91712 4.28475
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133950, 99307)
# *Cannot find tile image at level 17 for tile coordinate (66975, 49654)
# Retrieved image: 39.93023 3.96354 39.93999 3.95287
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.90884 4.29265 39.91862 4.28204
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.93232 3.96339 39.94208 3.95273
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.91113 4.29946 39.92091 4.28884
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.91242 4.29405 39.92221 4.28343
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134193, 99304)
# Retrieved image: 39.92469 4.28628 39.93448 4.27566
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134194, 99290)
# *Cannot find tile image at level 17 for tile coordinate (67097, 49645)
# Retrieved image: 39.93981 4.28848 39.94959 4.27786
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.94212 4.28509 39.9519 4.27447
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.94542 4.2855 39.9552 4.27488
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.94656 4.27325 39.95634 4.26263
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.94946 4.27701 39.95925 4.26638
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131320, 99087)
# *Cannot find tile image at level 17 for tile coordinate (65660, 49543)
# *Cannot find tile image at level 16 for tile coordinate (32830, 24771)
# *Cannot find tile image at level 15 for tile coordinate (16415, 12385)
# *Cannot find tile image at level 14 for tile coordinate (8207, 6192)
# Retrieved image: 40.15367 0.35282 40.16309 0.34161
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.95207 4.27875 39.96186 4.26813
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133854, 99249)
# *Cannot find tile image at level 17 for tile coordinate (66927, 49625)
# Retrieved image: 39.98419 3.83166 39.99393 3.82097
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.95585 4.26954 39.96563 4.25891
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.95757 4.27083 39.96736 4.2602
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.95743 4.27962 39.96722 4.269
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.95868 4.27867 39.96846 4.26805
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.96 4.2672 39.96978 4.25657
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134189, 99271)
# *Cannot find tile image at level 17 for tile coordinate (67095, 49635)
# Retrieved image: 39.95941 4.28466 39.96919 4.27404
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131213, 99080)
# Retrieved image: 40.16953 0.1942 40.17893 0.18297
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134184, 99269)
# *Cannot find tile image at level 17 for tile coordinate (67092, 49634)
# Retrieved image: 39.96162 4.28262 39.97141 4.272
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17115 0.18775 40.18055 0.17652
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17156 0.18847 40.18096 0.17724
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17165 0.18651 40.18105 0.17528
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.94745 3.18124 39.95713 3.17046
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.94719 3.18687 39.95688 3.17609
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17272 0.18616 40.18212 0.17492
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17295 0.18445 40.18235 0.17322
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17358 0.18235 40.18298 0.17111
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17393 0.18766 40.18333 0.17643
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17487 0.18531 40.18427 0.17408
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17531 0.18272 40.18471 0.17149
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17355 0.18799 40.18295 0.17676
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.17704 0.18469 40.18644 0.17345
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133830, 99227)
# *Cannot find tile image at level 17 for tile coordinate (66915, 49615)
# Retrieved image: 40.00627 3.79915 40.01601 3.78845
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18512 0.19664 40.19452 0.18541
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131237, 99060)
# *Cannot find tile image at level 17 for tile coordinate (65618, 49531)
# Retrieved image: 40.18627 0.22762 40.19567 0.21639
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131231, 99064)
# *Cannot find tile image at level 17 for tile coordinate (65616, 49532)
# Retrieved image: 40.18678 0.21991 40.19618 0.20868
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18725 0.21823 40.19665 0.20699
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.9847 4.2099 39.99448 4.19926
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18783 0.22096 40.19724 0.20973
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.98087 4.2689 39.99066 4.25827
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18882 0.21369 40.19822 0.20245
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.98626 4.21169 39.99604 4.20105
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18821 0.21614 40.19761 0.20491
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18996 0.22287 40.19936 0.21164
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19044 0.21971 40.19984 0.20848
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19055 0.21901 40.19995 0.20778
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.98733 4.21315 39.99711 4.20251
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.1914 0.22167 40.2008 0.21044
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19174 0.21342 40.20114 0.20219
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18974 0.22377 40.19914 0.21254
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19012 0.21514 40.19952 0.20391
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18786 0.21335 40.19726 0.20212
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.18772 0.21897 40.19712 0.20773
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19282 0.21831 40.20222 0.20708
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133834, 99217)
# *Cannot find tile image at level 17 for tile coordinate (66917, 49608)
# Retrieved image: 40.01655 3.80448 40.02629 3.79378
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131243, 99056)
# *Cannot find tile image at level 17 for tile coordinate (65620, 49529)
# Retrieved image: 40.1923 0.23619 40.2017 0.22496
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19332 0.21693 40.20273 0.20569
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.19423 0.22709 40.20364 0.21586
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99181 4.20902 40.00159 4.19838
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99214 4.20926 40.00192 4.19862
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99347 4.23019 40.00325 4.21955
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134152, 99238)
# Retrieved image: 39.99389 4.23205 40.00367 4.22141
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134152, 99238)
# Retrieved image: 39.99415 4.2387 40.00393 4.22806
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134181, 99240)
# *Cannot find tile image at level 17 for tile coordinate (67091, 49620)
# Retrieved image: 39.99173 4.27426 40.00151 4.26363
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (131262, 99048)
# *Cannot find tile image at level 17 for tile coordinate (65630, 49525)
# Retrieved image: 40.19882 0.26093 40.20823 0.2497
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134157, 99238)
# Retrieved image: 39.99467 4.24814 40.00445 4.2375
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134156, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67078, 49618)
# Retrieved image: 39.99482 4.24666 40.0046 4.23603
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134154, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67077, 49618)
# Retrieved image: 39.99544 4.2438 40.00522 4.23317
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134157, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67078, 49618)
# Retrieved image: 39.99573 4.24846 40.00551 4.23783
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134167, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67083, 49618)
# Retrieved image: 39.99507 4.26185 40.00485 4.25121
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134167, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67083, 49618)
# Retrieved image: 39.99522 4.26104 40.00501 4.25041
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.99439 4.2588 40.00418 4.24817
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134157, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67078, 49618)
# Retrieved image: 39.99519 4.24821 40.00497 4.23758
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134158, 99237)
# *Cannot find tile image at level 17 for tile coordinate (67079, 49618)
# Retrieved image: 39.99516 4.24882 40.00494 4.23819
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.9997 4.20504 40.00948 4.1944
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.00251 4.21177 40.01229 4.20113
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.0043 4.20862 40.01408 4.19797
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.00931 4.20977 40.01909 4.19913
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134142, 99223)
# *Cannot find tile image at level 17 for tile coordinate (67071, 49611)
# Retrieved image: 40.00986 4.21807 40.01964 4.20743
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134134, 99216)
# *Cannot find tile image at level 17 for tile coordinate (67067, 49608)
# Retrieved image: 40.01703 4.20717 40.02681 4.19653
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134134, 99216)
# *Cannot find tile image at level 17 for tile coordinate (67067, 49608)
# Retrieved image: 40.01699 4.21392 40.02677 4.20328
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.02296 4.13434 40.03273 4.12368
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# ...
# Retrieved image: 42.27666 3.29156 42.28634 3.28042
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27664 3.29829 42.28633 3.28714
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27789 3.30129 42.28757 3.29015
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27837 3.29311 42.28806 3.28197
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27925 3.28316 42.28893 3.27201
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27914 3.30231 42.28883 3.29117
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28049 3.28618 42.29018 3.27504
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27989 3.29165 42.28957 3.28051
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.27965 3.11596 42.28931 3.10479
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28136 3.28342 42.29104 3.27228
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28046 3.30409 42.29014 3.29295
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28187 3.28501 42.29155 3.27386
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28256 3.28462 42.29224 3.27348
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28444 3.30292 42.29412 3.29177
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28664 3.31466 42.29633 3.30351
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.2826 3.28583 42.29228 3.27469
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.29769 3.29765 42.30737 3.2865
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.29834 3.29355 42.30802 3.28241
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134162, 97062)
# *Cannot find tile image at level 17 for tile coordinate (67081, 48531)
# *Cannot find tile image at level 16 for tile coordinate (33540, 24265)
# *Cannot find tile image at level 15 for tile coordinate (16770, 12132)
# *Cannot find tile image at level 14 for tile coordinate (8385, 6066)
# Retrieved image: 42.24485 4.25524 42.25462 4.24424
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.30481 3.30871 42.31449 3.29757
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.3066 3.31255 42.31629 3.3014
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.30748 3.31535 42.31716 3.3042
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.30812 3.31805 42.31781 3.3069
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28794 3.29608 42.29763 3.28493
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.28803 3.29713 42.29771 3.28599
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31175 3.31807 42.32143 3.30692
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31241 3.32629 42.3221 3.31514
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31444 3.32731 42.32412 3.31617
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31483 3.33745 42.32452 3.32631
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31623 3.31546 42.32591 3.30432
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31839 3.31405 42.32807 3.3029
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.318 3.32191 42.32768 3.31076
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.32197 3.30645 42.33165 3.29531
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133469, 96985)
# *Cannot find tile image at level 17 for tile coordinate (66735, 48492)
# Retrieved image: 42.32295 3.29379 42.33263 3.28264
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.32233 3.31028 42.33201 3.29914
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133469, 96985)
# *Cannot find tile image at level 17 for tile coordinate (66735, 48492)
# Retrieved image: 42.32324 3.30406 42.33292 3.29291
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133467, 96984)
# *Cannot find tile image at level 17 for tile coordinate (66735, 48492)
# Retrieved image: 42.32408 3.29669 42.33377 3.28554
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133468, 96984)
# *Cannot find tile image at level 17 for tile coordinate (66735, 48492)
# Retrieved image: 42.32406 3.30226 42.33375 3.29111
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.32773 3.25595 42.33741 3.2448
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31792 3.32688 42.32761 3.31573
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.31791 3.33016 42.32759 3.31902
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133469, 96983)
# *Cannot find tile image at level 17 for tile coordinate (66734, 48491)
# Retrieved image: 42.32535 3.30364 42.33503 3.29249
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133463, 96981)
# *Cannot find tile image at level 17 for tile coordinate (66732, 48490)
# Retrieved image: 42.32713 3.29066 42.33681 3.27951
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133462, 96980)
# *Cannot find tile image at level 17 for tile coordinate (66732, 48490)
# Retrieved image: 42.32781 3.28512 42.33749 3.27397
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133462, 96980)
# *Cannot find tile image at level 17 for tile coordinate (66732, 48490)
# Retrieved image: 42.32771 3.28818 42.33739 3.27703
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133462, 96980)
# *Cannot find tile image at level 17 for tile coordinate (66732, 48490)
# Retrieved image: 42.32791 3.2919 42.33759 3.28075
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33038 3.25648 42.34006 3.24533
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.32999 3.26605 42.33967 3.25489
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.3339 3.20796 42.34357 3.1968
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33257 3.24632 42.34225 3.23516
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33191 3.267 42.34159 3.25584
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33307 3.24742 42.34275 3.23626
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33667 3.19544 42.34634 3.18427
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33615 3.20588 42.34582 3.19471
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133437, 96973)
# Retrieved image: 42.33487 3.24818 42.34455 3.23702
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133442, 96973)
# *Cannot find tile image at level 17 for tile coordinate (66721, 48486)
# Retrieved image: 42.33564 3.26708 42.34532 3.25593
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.33135 3.25172 42.34103 3.24056
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133432, 96969)
# *Cannot find tile image at level 17 for tile coordinate (66717, 48484)
# Retrieved image: 42.3394 3.24376 42.34907 3.2326
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133411, 96963)
# *Cannot find tile image at level 17 for tile coordinate (66705, 48481)
# Retrieved image: 42.34542 3.22362 42.35509 3.21245
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133385, 96960)
# *Cannot find tile image at level 17 for tile coordinate (66694, 48480)
# Retrieved image: 42.34828 3.18828 42.35796 3.17711
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133422, 96963)
# *Cannot find tile image at level 17 for tile coordinate (66711, 48481)
# Retrieved image: 42.34537 3.23972 42.35505 3.22856
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133378, 96941)
# *Cannot find tile image at level 17 for tile coordinate (66689, 48470)
# Retrieved image: 42.36775 3.16722 42.37742 3.15604
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133378, 96940)
# *Cannot find tile image at level 17 for tile coordinate (66689, 48470)
# Retrieved image: 42.3691 3.17189 42.37877 3.16072
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133378, 96939)
# *Cannot find tile image at level 17 for tile coordinate (66689, 48469)
# Retrieved image: 42.36979 3.16862 42.37946 3.15744
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.37855 3.16499 42.38822 3.15381
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133379, 96931)
# *Cannot find tile image at level 17 for tile coordinate (66689, 48468)
# Retrieved image: 42.38 3.16866 42.38967 3.15748
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133379, 96925)
# *Cannot find tile image at level 17 for tile coordinate (66690, 48462)
# Retrieved image: 42.3841 3.17327 42.39377 3.16209
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133379, 96912)
# *Cannot find tile image at level 17 for tile coordinate (66690, 48456)
# Retrieved image: 42.39666 3.17165 42.40633 3.16047
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133384, 96890)
# *Cannot find tile image at level 17 for tile coordinate (66692, 48445)
# Retrieved image: 42.41927 3.17542 42.42894 3.16423
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.42152 3.17211 42.43119 3.16093
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.4247 3.16955 42.43437 3.15837
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133383, 96892)
# Retrieved image: 42.42533 3.17429 42.435 3.16311
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133576, 96789)
# *Cannot find tile image at level 17 for tile coordinate (66788, 48394)
# *Cannot find tile image at level 16 for tile coordinate (33394, 24197)
# *Cannot find tile image at level 15 for tile coordinate (16697, 12098)
# *Cannot find tile image at level 14 for tile coordinate (8348, 6049)
# Retrieved image: 42.52144 3.45114 42.53114 3.43998
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (133830, 96717)
# *Cannot find tile image at level 17 for tile coordinate (66915, 48358)
# *Cannot find tile image at level 16 for tile coordinate (33457, 24179)
# *Cannot find tile image at level 15 for tile coordinate (16728, 12089)
# *Cannot find tile image at level 14 for tile coordinate (8364, 6044)
# Retrieved image: 42.59477 3.79913 42.6045 3.78801
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (134102, 96723)
# *Cannot find tile image at level 17 for tile coordinate (67051, 48361)
# *Cannot find tile image at level 16 for tile coordinate (33525, 24180)
# *Cannot find tile image at level 15 for tile coordinate (16762, 12090)
# *Cannot find tile image at level 14 for tile coordinate (8381, 6045)
# Retrieved image: 42.58842 4.17302 42.59818 4.16196
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.25529 3.17756 42.26496 3.1664
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 42.25524 3.17945 42.26491 3.1683
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-218618fa6b30> in <module>
#       1 #for i in range(0,1000): #do 1000 at a time
#       2 for i in range(1855, 3000):
# ----> 3     lat1=round(lat1_list[i],5)
#       4     lon1=round(lon1_list[i],5)
#       5     lat2=round(lat2_list[i],5)
#
# IndexError: list index out of range

# %%
#add farm ID to filename (quick fix)
#import os 

#folder = "/Users/Zack/0_thesis_bing/images_2019-10-13/"
#files = os.listdir(folder)
#print(files)

#sort files by date: newest to oldest
# search_dir = folder
# os.chdir(search_dir)
# files = filter(os.path.isfile, os.listdir(search_dir))
# files = [os.path.join(f) for f in files] 
# files.sort(key=lambda x: os.path.getmtime(x))
# print(len(files))

# #rename with farm ID
# for index, i in enumerate(files):
#     org = (i[11:])
#     name = (str(index))
#     dst = (name + org)
#     src = (i)
#     os.rename(src, dst)
