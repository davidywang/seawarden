# %%
#aerialImageRetrieval commandline in python
#%run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping
from aerialImageRetrieval import AerialImageRetrieval

#select country
n = 'ITA'

#load csv containing coordinates of polygon corners
f = '../targets_1_bing/'
file = f + 'sar_' + n + '.csv'
#file = f + '2019_g25_100m_10-20_1yr_02-01.csv'
targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))

tl = targets.drop(targets.index[0])
tl = tl.iloc[::5]
print(len(tl))

br = targets.drop(targets.index[0:3])
br = br.iloc[::5] 
print(len(br))

# create lists
lat1_list=tl['y'].tolist()
lon1_list=tl['x'].tolist()
lat2_list=br['y'].tolist()
lon2_list=br['x'].tolist()
# Out:
# 14035
# 2807
# 2807

# %%
#for i in range(0,1000): #do 1000 at a time
for i in range(0, 3000):
    lat1=round(lat1_list[i],5)
    lon1=round(lon1_list[i],5)
    lat2=round(lat2_list[i],5)
    lon2=round(lon2_list[i],5)
    
#     xy = mapping(centroids.geometry[i])['coordinates']
#     x = round(xy[0], 5)
#     y = round(xy[1], 5)

    #imgretrieval = AerialImageRetrieval(x, y, lat1, lon1, lat2, lon2)
    imgretrieval = AerialImageRetrieval(lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print("Retrieved image:", lat1, lon1, lat2, lon2)
    else:
        print("Cannot retrieve image:", lat1, lon1, lat2, lon2)
# Out:
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.70502 15.00357 36.71526 14.995
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.70511 15.00486 36.71534 14.99628
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.70231 15.03197 36.71255 15.0234
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.70646 15.01731 36.71669 15.00873
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.69635 15.11522 36.70659 15.10666
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.69676 15.11803 36.707 15.10947
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.69728 15.11849 36.70752 15.10993
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.69748 15.11803 36.70772 15.10947
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.69941 15.11961 36.70965 15.11106
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.69955 15.1192 36.70979 15.11064
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.7 15.1201 36.71024 15.11154
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 36.78888 15.09573 36.79913 15.08717
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139969, 101711)
# *Cannot find tile image at level 17 for tile coordinate (69984, 50855)
# *Cannot find tile image at level 16 for tile coordinate (34992, 25427)
# *Cannot find tile image at level 15 for tile coordinate (17496, 12713)
# *Cannot find tile image at level 14 for tile coordinate (8748, 6356)
# Retrieved image: 37.34267 12.22851 37.35281 12.21941
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139740, 101623)
# *Cannot find tile image at level 17 for tile coordinate (69870, 50811)
# *Cannot find tile image at level 16 for tile coordinate (34935, 25405)
# *Cannot find tile image at level 15 for tile coordinate (17467, 12702)
# *Cannot find tile image at level 14 for tile coordinate (8733, 6351)
# Retrieved image: 37.4387 11.9133 37.44882 11.90415
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.1413 15.22081 37.15157 15.21224
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.14216 15.22104 37.15242 15.21248
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.22987 15.19129 37.24013 15.18271
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.22999 15.19148 37.24026 15.1829
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139633, 101329)
# *Cannot find tile image at level 17 for tile coordinate (69816, 50664)
# *Cannot find tile image at level 16 for tile coordinate (34908, 25332)
# *Cannot find tile image at level 15 for tile coordinate (17454, 12666)
# *Cannot find tile image at level 14 for tile coordinate (8727, 6333)
# Retrieved image: 37.75855 11.76623 37.76867 11.75702
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139955, 101344)
# *Cannot find tile image at level 17 for tile coordinate (69977, 50672)
# *Cannot find tile image at level 16 for tile coordinate (34988, 25337)
# *Cannot find tile image at level 15 for tile coordinate (17494, 12669)
# Retrieved image: 37.74218 12.20828 37.75233 12.19914
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.33469 15.05323 37.34496 15.04462
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.33839 15.0515 37.34866 15.04289
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139304, 101225)
# *Cannot find tile image at level 17 for tile coordinate (69652, 50612)
# *Cannot find tile image at level 16 for tile coordinate (34826, 25306)
# *Cannot find tile image at level 15 for tile coordinate (17413, 12653)
# *Cannot find tile image at level 14 for tile coordinate (8706, 6326)
# Retrieved image: 37.87172 11.31478 37.88182 11.30549
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.34538 15.05774 37.35564 15.04913
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.34601 15.06429 37.35627 15.05568
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.35073 15.07458 37.36099 15.06598
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136717, 100857)
# *Cannot find tile image at level 17 for tile coordinate (68358, 50428)
# *Cannot find tile image at level 16 for tile coordinate (34179, 25214)
# *Cannot find tile image at level 15 for tile coordinate (17089, 12607)
# *Cannot find tile image at level 14 for tile coordinate (8544, 6303)
# Retrieved image: 38.26972 7.76337 38.27961 7.75346
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136370, 100783)
# *Cannot find tile image at level 17 for tile coordinate (68185, 50391)
# *Cannot find tile image at level 16 for tile coordinate (34092, 25195)
# *Cannot find tile image at level 15 for tile coordinate (17046, 12597)
# *Cannot find tile image at level 14 for tile coordinate (8523, 6298)
# Retrieved image: 38.34924 7.28612 38.3591 7.27613
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139064, 101128)
# *Cannot find tile image at level 17 for tile coordinate (69532, 50564)
# *Cannot find tile image at level 16 for tile coordinate (34766, 25282)
# *Cannot find tile image at level 15 for tile coordinate (17383, 12641)
# *Cannot find tile image at level 14 for tile coordinate (8691, 6320)
# Retrieved image: 37.97731 10.98532 37.9874 10.97596
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137064, 100826)
# *Cannot find tile image at level 17 for tile coordinate (68532, 50413)
# *Cannot find tile image at level 16 for tile coordinate (34266, 25206)
# *Cannot find tile image at level 15 for tile coordinate (17133, 12603)
# *Cannot find tile image at level 14 for tile coordinate (8566, 6301)
# Retrieved image: 38.3036 8.23874 38.31353 8.22891
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136072, 100704)
# *Cannot find tile image at level 17 for tile coordinate (68036, 50352)
# *Cannot find tile image at level 16 for tile coordinate (34018, 25176)
# *Cannot find tile image at level 15 for tile coordinate (17009, 12588)
# *Cannot find tile image at level 14 for tile coordinate (8504, 6294)
# Retrieved image: 38.43416 6.87675 38.444 6.86668
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.86494 12.45137 37.8751 12.44227
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.86578 12.45033 37.87594 12.44123
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.86841 12.44744 37.87857 12.43834
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.86856 12.44643 37.87872 12.43733
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.86991 12.44579 37.88007 12.43669
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.48846 15.1006 37.49873 15.09199
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 37.48902 15.098 37.49929 15.08939
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140030, 101198)
# *Cannot find tile image at level 17 for tile coordinate (70012, 50600)
# Retrieved image: 37.90706 12.30316 37.91722 12.29403
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140014, 101194)
# *Cannot find tile image at level 17 for tile coordinate (70007, 50598)
# Retrieved image: 37.9093 12.28973 37.91945 12.2806
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140017, 101197)
# *Cannot find tile image at level 17 for tile coordinate (70008, 50599)
# Retrieved image: 37.90907 12.29439 37.91922 12.28526
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140033, 101197)
# *Cannot find tile image at level 17 for tile coordinate (70016, 50599)
# Retrieved image: 37.90947 12.31566 37.91963 12.30653
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140032, 101197)
# Retrieved image: 37.91208 12.30666 37.92223 12.29753
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139835, 101138)
# *Cannot find tile image at level 17 for tile coordinate (69917, 50569)
# Retrieved image: 37.96574 12.04392 37.97588 12.03474
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139865, 101142)
# *Cannot find tile image at level 17 for tile coordinate (69933, 50571)
# Retrieved image: 37.9613 12.08114 37.97145 12.07197
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137421, 100759)
# *Cannot find tile image at level 17 for tile coordinate (68710, 50379)
# *Cannot find tile image at level 16 for tile coordinate (34355, 25189)
# *Cannot find tile image at level 15 for tile coordinate (17177, 12594)
# *Cannot find tile image at level 14 for tile coordinate (8588, 6297)
# Retrieved image: 38.37511 8.72903 38.38507 8.71926
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.00142 12.53173 38.01159 12.52264
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.00653 12.51867 38.0167 12.50957
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137755, 100698)
# *Cannot find tile image at level 17 for tile coordinate (68877, 50349)
# *Cannot find tile image at level 16 for tile coordinate (34438, 25174)
# *Cannot find tile image at level 15 for tile coordinate (17219, 12587)
# *Cannot find tile image at level 14 for tile coordinate (8609, 6293)
# Retrieved image: 38.44099 9.18874 38.45098 9.17904
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139260, 100880)
# *Cannot find tile image at level 17 for tile coordinate (69630, 50440)
# *Cannot find tile image at level 16 for tile coordinate (34815, 25220)
# *Cannot find tile image at level 15 for tile coordinate (17407, 12610)
# *Cannot find tile image at level 14 for tile coordinate (8703, 6305)
# Retrieved image: 38.24494 11.25463 38.25505 11.24529
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (138956, 100813)
# *Cannot find tile image at level 17 for tile coordinate (69478, 50406)
# *Cannot find tile image at level 16 for tile coordinate (34739, 25203)
# *Cannot find tile image at level 15 for tile coordinate (17369, 12601)
# *Cannot find tile image at level 14 for tile coordinate (8684, 6300)
# Retrieved image: 38.31743 10.83649 38.32751 10.82708
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (135986, 100411)
# *Cannot find tile image at level 17 for tile coordinate (67993, 50205)
# *Cannot find tile image at level 16 for tile coordinate (33996, 25102)
# *Cannot find tile image at level 15 for tile coordinate (16998, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8499, 6275)
# Retrieved image: 38.74908 6.75873 38.75891 6.74861
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (138002, 100653)
# *Cannot find tile image at level 17 for tile coordinate (69001, 50326)
# *Cannot find tile image at level 16 for tile coordinate (34500, 25163)
# *Cannot find tile image at level 15 for tile coordinate (17250, 12581)
# *Cannot find tile image at level 14 for tile coordinate (8625, 6290)
# Retrieved image: 38.48877 9.52697 38.49878 9.51732
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139624, 100880)
# *Cannot find tile image at level 17 for tile coordinate (69812, 50440)
# *Cannot find tile image at level 16 for tile coordinate (34906, 25220)
# *Cannot find tile image at level 15 for tile coordinate (17453, 12610)
# *Cannot find tile image at level 14 for tile coordinate (8726, 6305)
# Retrieved image: 38.24493 11.75459 38.25506 11.74534
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (138591, 100708)
# *Cannot find tile image at level 17 for tile coordinate (69295, 50354)
# *Cannot find tile image at level 16 for tile coordinate (34647, 25177)
# *Cannot find tile image at level 15 for tile coordinate (17323, 12588)
# *Cannot find tile image at level 14 for tile coordinate (8661, 6294)
# Retrieved image: 38.43003 10.3356 38.44009 10.32609
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136347, 100415)
# *Cannot find tile image at level 17 for tile coordinate (68173, 50207)
# *Cannot find tile image at level 16 for tile coordinate (34086, 25103)
# *Cannot find tile image at level 15 for tile coordinate (17043, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8521, 6275)
# Retrieved image: 38.74506 7.25505 38.75493 7.24501
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (135669, 100339)
# *Cannot find tile image at level 17 for tile coordinate (67834, 50169)
# *Cannot find tile image at level 16 for tile coordinate (33917, 25084)
# *Cannot find tile image at level 15 for tile coordinate (16958, 12542)
# *Cannot find tile image at level 14 for tile coordinate (8479, 6271)
# Retrieved image: 38.82589 6.32393 38.8357 6.31374
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136711, 100415)
# *Cannot find tile image at level 17 for tile coordinate (68355, 50207)
# *Cannot find tile image at level 16 for tile coordinate (34177, 25103)
# *Cannot find tile image at level 15 for tile coordinate (17088, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8544, 6275)
# Retrieved image: 38.74504 7.75502 38.75495 7.74505
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139961, 100878)
# *Cannot find tile image at level 17 for tile coordinate (69980, 50439)
# Retrieved image: 38.24708 12.21756 38.25724 12.20839
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137074, 100417)
# *Cannot find tile image at level 17 for tile coordinate (68537, 50208)
# *Cannot find tile image at level 16 for tile coordinate (34268, 25104)
# *Cannot find tile image at level 15 for tile coordinate (17134, 12552)
# *Cannot find tile image at level 14 for tile coordinate (8567, 6276)
# Retrieved image: 38.74298 8.25345 38.75292 8.24357
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137436, 100447)
# *Cannot find tile image at level 17 for tile coordinate (68718, 50223)
# *Cannot find tile image at level 16 for tile coordinate (34359, 25111)
# *Cannot find tile image at level 15 for tile coordinate (17179, 12555)
# *Cannot find tile image at level 14 for tile coordinate (8589, 6277)
# Retrieved image: 38.7105 8.74963 38.72047 8.73984
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137804, 100415)
# *Cannot find tile image at level 17 for tile coordinate (68902, 50207)
# *Cannot find tile image at level 16 for tile coordinate (34451, 25103)
# *Cannot find tile image at level 15 for tile coordinate (17225, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8612, 6275)
# Retrieved image: 38.74468 9.25517 38.75468 9.24545
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (138162, 100395)
# *Cannot find tile image at level 17 for tile coordinate (69081, 50197)
# *Cannot find tile image at level 16 for tile coordinate (34540, 25098)
# *Cannot find tile image at level 15 for tile coordinate (17270, 12549)
# *Cannot find tile image at level 14 for tile coordinate (8635, 6274)
# Retrieved image: 38.76566 9.747 38.77569 9.73736
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137334, 100278)
# *Cannot find tile image at level 17 for tile coordinate (68667, 50139)
# Retrieved image: 38.89153 8.61036 38.90149 8.60052
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136389, 100160)
# *Cannot find tile image at level 17 for tile coordinate (68194, 50080)
# *Cannot find tile image at level 16 for tile coordinate (34097, 25040)
# *Cannot find tile image at level 15 for tile coordinate (17048, 12520)
# *Cannot find tile image at level 14 for tile coordinate (8524, 6260)
# Retrieved image: 39.01684 7.31197 39.02672 7.30191
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137501, 100302)
# *Cannot find tile image at level 17 for tile coordinate (68750, 50151)
# Retrieved image: 38.87067 8.83998 38.88065 8.83018
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137495, 100297)
# *Cannot find tile image at level 17 for tile coordinate (68747, 50149)
# Retrieved image: 38.87656 8.83078 38.88654 8.82097
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (136304, 100142)
# *Cannot find tile image at level 17 for tile coordinate (68152, 50071)
# *Cannot find tile image at level 16 for tile coordinate (34076, 25035)
# *Cannot find tile image at level 15 for tile coordinate (17038, 12517)
# *Cannot find tile image at level 14 for tile coordinate (8519, 6258)
# Retrieved image: 39.03629 7.19519 39.04617 7.18511
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137530, 100296)
# *Cannot find tile image at level 17 for tile coordinate (68765, 50148)
# Retrieved image: 38.87708 8.86981 38.88706 8.86002
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.88958 8.80863 38.89956 8.79883
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137221, 100236)
# *Cannot find tile image at level 17 for tile coordinate (68610, 50118)
# Retrieved image: 38.9364 8.45512 38.94635 8.44525
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (138532, 100414)
# *Cannot find tile image at level 17 for tile coordinate (69266, 50207)
# *Cannot find tile image at level 16 for tile coordinate (34633, 25103)
# *Cannot find tile image at level 15 for tile coordinate (17316, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8658, 6275)
# Retrieved image: 38.74581 10.25555 38.75588 10.246
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137341, 100248)
# *Cannot find tile image at level 17 for tile coordinate (68670, 50124)
# Retrieved image: 38.92275 8.6203 38.93271 8.61046
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137451, 100266)
# *Cannot find tile image at level 17 for tile coordinate (68725, 50134)
# Retrieved image: 38.90919 8.77037 38.91916 8.76056
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.9217 8.72526 38.93167 8.71544
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.92278 8.7243 38.93275 8.71448
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.95062 8.6247 38.96059 8.61486
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.95522 8.62079 38.96519 8.61094
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137342, 100249)
# *Cannot find tile image at level 17 for tile coordinate (68671, 50124)
# Retrieved image: 38.92248 8.62108 38.93245 8.61124
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.95806 8.62203 38.96802 8.61219
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.95641 8.63896 38.96638 8.62912
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.95923 8.62715 38.9692 8.61731
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.96481 8.61491 38.97478 8.60507
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.96738 8.61402 38.97735 8.60418
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.97346 8.60669 38.98342 8.59684
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.98045 8.60314 38.99042 8.59329
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.98028 8.60579 38.99024 8.59594
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (138896, 100415)
# *Cannot find tile image at level 17 for tile coordinate (69448, 50207)
# *Cannot find tile image at level 16 for tile coordinate (34724, 25103)
# *Cannot find tile image at level 15 for tile coordinate (17362, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8681, 6275)
# Retrieved image: 38.74495 10.75469 38.75504 10.74523
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137230, 100161)
# *Cannot find tile image at level 17 for tile coordinate (68615, 50081)
# Retrieved image: 39.02093 8.45798 39.03089 8.4481
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.01037 8.59532 39.02034 8.58547
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137242, 100155)
# *Cannot find tile image at level 17 for tile coordinate (68621, 50077)
# Retrieved image: 39.02207 8.48424 39.03203 8.47437
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.01248 8.59596 39.02244 8.58611
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.01281 8.59298 39.02278 8.58312
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.01425 8.59039 39.02421 8.58053
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.01536 8.59054 39.02533 8.58069
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137281, 100155)
# *Cannot find tile image at level 17 for tile coordinate (68640, 50077)
# Retrieved image: 39.02248 8.53734 39.03244 8.52748
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.01915 8.5894 39.02911 8.57955
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.97766 9.00355 38.98765 8.99376
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.97915 9.00605 38.98914 8.99627
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (135686, 99964)
# *Cannot find tile image at level 17 for tile coordinate (67843, 49982)
# *Cannot find tile image at level 16 for tile coordinate (33921, 24991)
# *Cannot find tile image at level 15 for tile coordinate (16960, 12495)
# *Cannot find tile image at level 14 for tile coordinate (8480, 6247)
# Retrieved image: 39.22603 6.3473 39.23584 6.33705
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 38.98097 9.00951 38.99097 8.99973
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137238, 100145)
# *Cannot find tile image at level 17 for tile coordinate (68619, 50073)
# Retrieved image: 39.0369 8.46773 39.04685 8.45785
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137645, 100195)
# *Cannot find tile image at level 17 for tile coordinate (68823, 50097)
# Retrieved image: 38.97983 9.02849 38.98982 9.01871
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.02761 8.58509 39.03758 8.57523
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0396 8.46617 39.04956 8.45629
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.02841 8.58541 39.03838 8.57555
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.03179 8.58323 39.04176 8.57337
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.03231 8.58399 39.04228 8.57414
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.04419 8.46686 39.05415 8.45698
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137312, 100153)
# Retrieved image: 39.03501 8.57982 39.04497 8.56996
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137242, 100140)
# *Cannot find tile image at level 17 for tile coordinate (68621, 50071)
# Retrieved image: 39.04582 8.47396 39.05578 8.46408
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137244, 100139)
# *Cannot find tile image at level 17 for tile coordinate (68622, 50070)
# Retrieved image: 39.04654 8.47664 39.0565 8.46676
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0361 8.58327 39.04606 8.57341
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.03587 8.58183 39.04584 8.57197
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137246, 100136)
# *Cannot find tile image at level 17 for tile coordinate (68623, 50068)
# Retrieved image: 39.04628 8.47935 39.05624 8.46947
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137301, 100144)
# *Cannot find tile image at level 17 for tile coordinate (68651, 50072)
# Retrieved image: 39.04042 8.55643 39.05038 8.54656
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137301, 100144)
# *Cannot find tile image at level 17 for tile coordinate (68651, 50072)
# Retrieved image: 39.04196 8.56227 39.05193 8.55241
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137301, 100144)
# Retrieved image: 39.04317 8.55478 39.05313 8.54492
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137301, 100144)
# *Cannot find tile image at level 17 for tile coordinate (68651, 50072)
# Retrieved image: 39.04251 8.55595 39.05248 8.54609
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.04514 8.55739 39.0551 8.54753
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137301, 100144)
# *Cannot find tile image at level 17 for tile coordinate (68651, 50072)
# Retrieved image: 39.04452 8.56409 39.05448 8.55423
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.04616 8.55312 39.05613 8.54325
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.04792 8.54923 39.05788 8.53936
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137649, 100178)
# *Cannot find tile image at level 17 for tile coordinate (68825, 50089)
# Retrieved image: 38.99845 9.03712 39.00845 9.02734
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (139260, 100415)
# *Cannot find tile image at level 17 for tile coordinate (69630, 50207)
# *Cannot find tile image at level 16 for tile coordinate (34815, 25103)
# *Cannot find tile image at level 15 for tile coordinate (17407, 12551)
# *Cannot find tile image at level 14 for tile coordinate (8703, 6275)
# Retrieved image: 38.74494 11.25465 38.75506 11.24527
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137257, 100129)
# *Cannot find tile image at level 17 for tile coordinate (68627, 50065)
# Retrieved image: 39.05701 8.49472 39.06697 8.48484
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137145, 100109)
# *Cannot find tile image at level 17 for tile coordinate (68572, 50054)
# Retrieved image: 39.0715 8.35039 39.08146 8.34049
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137281, 100134)
# *Cannot find tile image at level 17 for tile coordinate (68640, 50067)
# Retrieved image: 39.0545 8.53687 39.06447 8.527
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137268, 100131)
# *Cannot find tile image at level 17 for tile coordinate (68634, 50066)
# Retrieved image: 39.05685 8.51976 39.06682 8.50989
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137281, 100134)
# *Cannot find tile image at level 17 for tile coordinate (68640, 50067)
# Retrieved image: 39.05544 8.53724 39.06541 8.52737
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05869 8.52083 39.06865 8.51096
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06091 8.50192 39.07087 8.49205
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06157 8.49813 39.07153 8.48826
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137257, 100129)
# Retrieved image: 39.05993 8.50395 39.0699 8.49408
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137272, 100131)
# Retrieved image: 39.05799 8.52487 39.06795 8.515
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05737 8.54079 39.06734 8.53092
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05776 8.53799 39.06773 8.52812
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06015 8.5156 39.07011 8.50573
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05984 8.51863 39.0698 8.50876
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06091 8.50611 39.07087 8.49624
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06118 8.50367 39.07114 8.4938
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05807 8.5333 39.06804 8.52343
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06203 8.50315 39.07199 8.49327
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06412 8.48322 39.07408 8.47334
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0628 8.4981 39.07276 8.48823
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06327 8.49622 39.07323 8.48635
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05969 8.53155 39.06965 8.52168
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05948 8.53383 39.06944 8.52396
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05884 8.54293 39.06881 8.53306
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06299 8.50439 39.07296 8.49452
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.062 8.51986 39.07197 8.50999
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06093 8.52395 39.07089 8.51408
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06025 8.53205 39.07021 8.52218
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05893 8.54164 39.0689 8.53177
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06142 8.51712 39.07139 8.50725
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05927 8.53997 39.06924 8.53011
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.05935 8.52544 39.06931 8.51557
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0615 8.50447 39.07146 8.4946
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06419 8.50036 39.07415 8.49048
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.061 8.53305 39.07096 8.52318
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06033 8.54196 39.07029 8.53209
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06492 8.50228 39.07488 8.4924
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06231 8.52412 39.07227 8.51425
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06055 8.53911 39.07051 8.52924
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06279 8.51727 39.07276 8.5074
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06423 8.5043 39.07419 8.49443
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06192 8.5405 39.07188 8.53064
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06585 8.50143 39.07581 8.49155
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06473 8.51883 39.07469 8.50895
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06574 8.50361 39.0757 8.49374
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06425 8.52559 39.07421 8.51572
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06463 8.52268 39.07459 8.5128
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06539 8.51539 39.07536 8.50552
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06666 8.50843 39.07662 8.49856
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06721 8.50958 39.07717 8.49971
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06693 8.52361 39.07689 8.51374
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06999 8.49426 39.07995 8.48438
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0681 8.51544 39.07806 8.50557
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06794 8.52203 39.07791 8.51215
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07136 8.49591 39.08132 8.48603
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07025 8.51323 39.08022 8.50336
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.06944 8.5167 39.07941 8.50682
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07019 8.516 39.08015 8.50613
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07699 8.46819 39.08695 8.45831
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07371 8.51947 39.08368 8.5096
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137123, 100089)
# *Cannot find tile image at level 17 for tile coordinate (68561, 50046)
# Retrieved image: 39.09526 8.31079 39.10521 8.30088
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0777 8.49838 39.08767 8.4885
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07471 8.51794 39.08468 8.50807
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07503 8.51487 39.08499 8.505
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0797 8.48841 39.08966 8.47853
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07741 8.50899 39.08738 8.49911
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07663 8.51764 39.08659 8.50777
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.08005 8.49051 39.09001 8.48063
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.0769 8.51805 39.08686 8.50817
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137653, 100155)
# *Cannot find tile image at level 17 for tile coordinate (68826, 50080)
# Retrieved image: 39.02425 9.0387 39.03425 9.02892
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07903 8.50554 39.08899 8.49566
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07786 8.51944 39.08782 8.50957
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07975 8.50417 39.08972 8.4943
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.08004 8.50287 39.09001 8.49299
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.08024 8.50231 39.09021 8.49243
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (135983, 99946)
# *Cannot find tile image at level 17 for tile coordinate (67991, 49973)
# *Cannot find tile image at level 16 for tile coordinate (33995, 24986)
# *Cannot find tile image at level 15 for tile coordinate (16997, 12493)
# *Cannot find tile image at level 14 for tile coordinate (8498, 6246)
# Retrieved image: 39.24508 6.75512 39.25492 6.74494
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.09406 8.4399 39.10402 8.43001
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07786 8.51468 39.08782 8.5048
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.07852 8.50722 39.08848 8.49735
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.09902 8.42802 39.10898 8.41813
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.10041 8.44264 39.11037 8.43275
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.10888 8.3791 39.11883 8.3692
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.10979 8.37511 39.11974 8.36521
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.11194 8.37541 39.12189 8.36551
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.10751 8.44226 39.11747 8.43237
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.12625 8.25401 39.1362 8.24409
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.10954 8.37626 39.1195 8.36636
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.10753 8.47702 39.1175 8.46713
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (137056, 100052)
# *Cannot find tile image at level 17 for tile coordinate (68528, 50027)
# Retrieved image: 39.13442 8.22874 39.14436 8.21881
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.13094 8.30988 39.14089 8.29997
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 39.11603 8.46471 39.12599 8.45483
# ...
# *Cannot find tile image at level 16 for tile coordinate (35282, 23816)
# *Cannot find tile image at level 15 for tile coordinate (17641, 11908)
# *Cannot find tile image at level 14 for tile coordinate (8820, 5954)
# Retrieved image: 44.04499 13.82199 44.05542 13.81256
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141111, 95250)
# *Cannot find tile image at level 17 for tile coordinate (70555, 47625)
# *Cannot find tile image at level 16 for tile coordinate (35277, 23812)
# *Cannot find tile image at level 15 for tile coordinate (17638, 11906)
# *Cannot find tile image at level 14 for tile coordinate (8819, 5953)
# Retrieved image: 44.05883 13.79644 44.06926 13.787
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141090, 95245)
# *Cannot find tile image at level 17 for tile coordinate (70545, 47622)
# *Cannot find tile image at level 16 for tile coordinate (35272, 23811)
# *Cannot find tile image at level 15 for tile coordinate (17636, 11905)
# *Cannot find tile image at level 14 for tile coordinate (8818, 5952)
# Retrieved image: 44.0642 13.76769 44.07463 13.75824
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140372, 95097)
# *Cannot find tile image at level 17 for tile coordinate (70186, 47548)
# *Cannot find tile image at level 16 for tile coordinate (35093, 23774)
# *Cannot find tile image at level 15 for tile coordinate (17546, 11887)
# *Cannot find tile image at level 14 for tile coordinate (8773, 5943)
# Retrieved image: 44.20925 12.7818 44.21962 12.77213
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140319, 95082)
# *Cannot find tile image at level 17 for tile coordinate (70159, 47541)
# *Cannot find tile image at level 16 for tile coordinate (35079, 23770)
# *Cannot find tile image at level 15 for tile coordinate (17539, 11885)
# *Cannot find tile image at level 14 for tile coordinate (8769, 5942)
# Retrieved image: 44.22413 12.70967 44.2345 12.69998
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140617, 95142)
# *Cannot find tile image at level 17 for tile coordinate (70308, 47571)
# *Cannot find tile image at level 16 for tile coordinate (35154, 23785)
# *Cannot find tile image at level 15 for tile coordinate (17577, 11892)
# *Cannot find tile image at level 14 for tile coordinate (8788, 5946)
# Retrieved image: 44.1659 13.11837 44.17629 13.10877
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141024, 95221)
# *Cannot find tile image at level 17 for tile coordinate (70512, 47610)
# *Cannot find tile image at level 16 for tile coordinate (35256, 23805)
# *Cannot find tile image at level 15 for tile coordinate (17628, 11902)
# *Cannot find tile image at level 14 for tile coordinate (8814, 5951)
# Retrieved image: 44.08711 13.67777 44.09754 13.6683
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141104, 95237)
# *Cannot find tile image at level 17 for tile coordinate (70552, 47618)
# *Cannot find tile image at level 16 for tile coordinate (35276, 23809)
# *Cannot find tile image at level 15 for tile coordinate (17638, 11904)
# *Cannot find tile image at level 14 for tile coordinate (8819, 5952)
# Retrieved image: 44.07205 13.78657 44.08248 13.77712
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141086, 95227)
# *Cannot find tile image at level 17 for tile coordinate (70543, 47613)
# *Cannot find tile image at level 16 for tile coordinate (35271, 23806)
# *Cannot find tile image at level 15 for tile coordinate (17635, 11903)
# *Cannot find tile image at level 14 for tile coordinate (8817, 5951)
# Retrieved image: 44.08125 13.76249 44.09167 13.75304
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141074, 95222)
# *Cannot find tile image at level 17 for tile coordinate (70537, 47611)
# *Cannot find tile image at level 16 for tile coordinate (35268, 23805)
# *Cannot find tile image at level 15 for tile coordinate (17634, 11902)
# *Cannot find tile image at level 14 for tile coordinate (8817, 5951)
# Retrieved image: 44.08646 13.74617 44.09689 13.73672
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (141007, 95205)
# *Cannot find tile image at level 17 for tile coordinate (70503, 47602)
# *Cannot find tile image at level 16 for tile coordinate (35251, 23801)
# *Cannot find tile image at level 15 for tile coordinate (17625, 11900)
# *Cannot find tile image at level 14 for tile coordinate (8812, 5950)
# Retrieved image: 44.10372 13.65355 44.11415 13.64407
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140415, 95064)
# *Cannot find tile image at level 17 for tile coordinate (70207, 47532)
# *Cannot find tile image at level 16 for tile coordinate (35103, 23766)
# *Cannot find tile image at level 15 for tile coordinate (17551, 11883)
# *Cannot find tile image at level 14 for tile coordinate (8775, 5941)
# Retrieved image: 44.24193 12.84055 44.25231 12.83088
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140592, 95083)
# *Cannot find tile image at level 17 for tile coordinate (70296, 47541)
# *Cannot find tile image at level 16 for tile coordinate (35148, 23770)
# *Cannot find tile image at level 15 for tile coordinate (17574, 11885)
# *Cannot find tile image at level 14 for tile coordinate (8787, 5942)
# Retrieved image: 44.22349 13.08367 44.23388 13.07406
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140699, 95095)
# *Cannot find tile image at level 17 for tile coordinate (70349, 47547)
# *Cannot find tile image at level 16 for tile coordinate (35174, 23773)
# *Cannot find tile image at level 15 for tile coordinate (17587, 11886)
# *Cannot find tile image at level 14 for tile coordinate (8793, 5943)
# Retrieved image: 44.21148 13.23025 44.22188 13.22067
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140349, 94966)
# *Cannot find tile image at level 17 for tile coordinate (70174, 47483)
# *Cannot find tile image at level 16 for tile coordinate (35087, 23741)
# *Cannot find tile image at level 15 for tile coordinate (17543, 11870)
# *Cannot find tile image at level 14 for tile coordinate (8771, 5935)
# Retrieved image: 44.33814 12.7503 44.34851 12.7406
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140831, 94987)
# *Cannot find tile image at level 17 for tile coordinate (70415, 47493)
# *Cannot find tile image at level 16 for tile coordinate (35207, 23746)
# *Cannot find tile image at level 15 for tile coordinate (17603, 11873)
# *Cannot find tile image at level 14 for tile coordinate (8801, 5936)
# Retrieved image: 44.31748 13.41201 44.3279 13.40245
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140548, 94805)
# *Cannot find tile image at level 17 for tile coordinate (70274, 47402)
# *Cannot find tile image at level 16 for tile coordinate (35137, 23701)
# *Cannot find tile image at level 15 for tile coordinate (17568, 11850)
# *Cannot find tile image at level 14 for tile coordinate (8784, 5925)
# Retrieved image: 44.49639 13.02362 44.50679 13.01397
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140448, 94739)
# *Cannot find tile image at level 17 for tile coordinate (70224, 47369)
# *Cannot find tile image at level 16 for tile coordinate (35112, 23684)
# *Cannot find tile image at level 15 for tile coordinate (17556, 11842)
# *Cannot find tile image at level 14 for tile coordinate (8778, 5921)
# Retrieved image: 44.56129 12.88638 44.57168 12.87669
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140423, 94613)
# *Cannot find tile image at level 17 for tile coordinate (70211, 47306)
# *Cannot find tile image at level 16 for tile coordinate (35105, 23653)
# *Cannot find tile image at level 15 for tile coordinate (17552, 11826)
# *Cannot find tile image at level 14 for tile coordinate (8776, 5913)
# Retrieved image: 44.68397 12.85227 44.69436 12.84255
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140423, 94554)
# *Cannot find tile image at level 17 for tile coordinate (70211, 47277)
# *Cannot find tile image at level 16 for tile coordinate (35105, 23638)
# *Cannot find tile image at level 15 for tile coordinate (17552, 11819)
# *Cannot find tile image at level 14 for tile coordinate (8776, 5909)
# Retrieved image: 44.74156 12.85236 44.75195 12.84264
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140575, 94575)
# *Cannot find tile image at level 17 for tile coordinate (70287, 47287)
# *Cannot find tile image at level 16 for tile coordinate (35143, 23643)
# *Cannot find tile image at level 15 for tile coordinate (17571, 11821)
# *Cannot find tile image at level 14 for tile coordinate (8785, 5910)
# Retrieved image: 44.72079 13.06036 44.73119 13.05069
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140432, 94040)
# *Cannot find tile image at level 17 for tile coordinate (70216, 47020)
# *Cannot find tile image at level 16 for tile coordinate (35108, 23510)
# *Cannot find tile image at level 15 for tile coordinate (17554, 11755)
# *Cannot find tile image at level 14 for tile coordinate (8777, 5877)
# Retrieved image: 45.24118 12.86451 45.25158 12.85473
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.3393 13.07764 45.34972 13.06789
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# *Cannot find tile image at level 18 for tile coordinate (140457, 93726)
# *Cannot find tile image at level 17 for tile coordinate (70228, 46863)
# Retrieved image: 45.54402 12.89894 45.55443 12.88913
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.61558 13.23901 45.62602 13.22926
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.65743 13.16739 45.66787 13.15761
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.61311 13.56998 45.62357 13.5603
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.65082 13.44336 45.66127 13.43365
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.69194 13.16516 45.70238 13.15538
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.60421 13.7585 45.61468 13.74886
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.59964 13.79819 45.61012 13.78856
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.60445 13.7876 45.61493 13.77797
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.60701 13.78192 45.61748 13.77229
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.60623 13.79 45.6167 13.78037
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.60746 13.78332 45.61793 13.77368
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.61923 13.74195 45.6297 13.73231
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.62985 13.74219 45.64032 13.73254
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.6372 13.74317 45.64767 13.73352
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.64414 13.75653 45.65462 13.74688
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.64419 13.76414 45.65466 13.7545
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.6747 13.62296 45.68517 13.61328
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.65417 13.76497 45.66464 13.75533
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.71641 13.57641 45.72688 13.56672
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.74143 13.60736 45.75189 13.59767
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.74978 13.59137 45.76025 13.58168
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.7563 13.58189 45.76676 13.5722
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.75805 13.58414 45.76851 13.57445
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.76267 13.5726 45.77314 13.5629
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.75945 13.59673 45.76991 13.58704
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.76051 13.59634 45.77098 13.58664
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.76437 13.57491 45.77483 13.56522
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.77051 13.56112 45.78097 13.55142
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.76349 13.63336 45.77396 13.62368
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 45.77544 13.55433 45.78591 13.54463
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-3fc7ca09fbdd> in <module>
#       1 #for i in range(0,1000): #do 1000 at a time
#       2 for i in range(0, 3000):
# ----> 3     lat1=round(lat1_list[i],5)
#       4     lon1=round(lon1_list[i],5)
#       5     lat2=round(lat2_list[i],5)
#
# IndexError: list index out of range

# %%
#add farm ID to filename (quick fix)
#import os 

#folder = "/Users/Zack/0_thesis_bing/images_2019-10-13/"
#files = os.listdir(folder)
#print(files)

#sort files by date: newest to oldest
# search_dir = folder
# os.chdir(search_dir)
# files = filter(os.path.isfile, os.listdir(search_dir))
# files = [os.path.join(f) for f in files] 
# files.sort(key=lambda x: os.path.getmtime(x))
# print(len(files))

# #rename with farm ID
# for index, i in enumerate(files):
#     org = (i[11:])
#     name = (str(index))
#     dst = (name + org)
#     src = (i)
#     os.rename(src, dst)
