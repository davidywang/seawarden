# %%
#https://windrose.readthedocs.io/en/latest/usage.html
#https://stackoverflow.com/questions/50821406/custom-scaling-of-wind-rose-python
#https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

import os 
import pandas as pd
from windrose import WindroseAxes
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
#load CSVs
folder = '/Users/Zack/0_thesis_ocean_current_2/medsea_current_csv/'
#folder = '/Users/Zack/Desktop/csv/'
files = os.listdir(folder)
print(len(files))
# Out:
# 30

# %%
#sort CSV files
os.chdir(folder)
files = filter(os.path.isfile, os.listdir(folder))
files = [os.path.join(f) for f in files] 
files.sort(key=lambda x: os.path.getmtime(x))
print(len(files))
# Out:
# 30

# %%
#plot function
def plot_rose(wd, ws, name):
    ax = WindroseAxes.from_ax()
    ax.bar(wd, ws, normed=True, opening=.75, edgecolor='white', cmap=cm.summer) #_r)
    ax.set_yticks(np.arange(5, 25, step=5))
    ax.set_yticklabels(np.arange(5, 25, step=5))
    ax.set_legend(loc='center', bbox_to_anchor=(.5, -.1), ncol = 6, prop={'size': 12})
    #ax.set_legend(loc=3,ncol=6, mode="expand", borderaxespad=0.)
    plt.title('Farm Site ' + name[:2] + ': Ocean Current and Direction')

# %%
#plot tester
file = folder + files[1]
csv = pd.read_csv(file)
ws = csv['speed']
wd = csv['dir']
plot_rose(wd, ws, files[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-976c04056087> in <module>
#       4 ws = csv['speed']
#       5 wd = csv['dir']
# ----> 6 plot_rose(wd, ws, files[1])
#
# <ipython-input-4-7bbde0b5b340> in plot_rose(wd, ws, name)
#       2 def plot_rose(wd, ws, name):
#       3     ax = WindroseAxes.from_ax()
# ----> 4     ax.bar(wd, ws, normed=True, opening=.75, edgecolor='white', cmap=cm.summer) #_r)
#       5     ax.set_yticks(np.arange(5, 25, step=5))
#       6     ax.set_yticklabels(np.arange(5, 25, step=5))
#
# ~\Anaconda3\envs\thesis\lib\site-packages\windrose\windrose.py in bar(self, direction, var, **kwargs)
#     542
#     543         bins, nbins, nsector, colors, angles, kwargs = self._init_plot(
# --> 544             direction, var, **kwargs
#     545         )
#     546         kwargs.pop("facecolor", None)
#
# ~\Anaconda3\envs\thesis\lib\site-packages\windrose\windrose.py in _init_plot(self, direction, var, **kwargs)
#     311         bins = kwargs.pop("bins", None)
#     312         if bins is None:
# --> 313             bins = np.linspace(np.min(var), np.max(var), 6)
#     314         if isinstance(bins, int):
#     315             bins = np.linspace(np.min(var), np.max(var), bins)
#
# ~\Anaconda3\envs\thesis\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     133     # Convert float/complex array scalars to float, gh-3504
#     134     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 135     start = asanyarray(start) * 1.0
#     136     stop  = asanyarray(stop)  * 1.0
#     137
#
# TypeError: ufunc 'multiply' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')

# %%
out_dir = '/Users/Zack/0_thesis_ocean_current_2/plots'

for i in range(len(files)):
    file = folder + files[i]
    csv = pd.read_csv(file)
    plot_rose(wd=csv['dir'], ws=csv['speed'], name = files[i]) 
    filename = out_dir + files[i][:17] + '_plot.png'
    plot = plt.savefig(filename)
    plt.close(plot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7fd72d5c70b0> in <module>
#       4     file = folder + files[i]
#       5     csv = pd.read_csv(file)
# ----> 6     plot_rose(wd=csv['dir'], ws=csv['speed'], name = files[i])
#       7     filename = out_dir + files[i][:17] + '_plot.png'
#       8     plot = plt.savefig(filename)
#
# <ipython-input-4-7bbde0b5b340> in plot_rose(wd, ws, name)
#       2 def plot_rose(wd, ws, name):
#       3     ax = WindroseAxes.from_ax()
# ----> 4     ax.bar(wd, ws, normed=True, opening=.75, edgecolor='white', cmap=cm.summer) #_r)
#       5     ax.set_yticks(np.arange(5, 25, step=5))
#       6     ax.set_yticklabels(np.arange(5, 25, step=5))
#
# ~\Anaconda3\envs\thesis\lib\site-packages\windrose\windrose.py in bar(self, direction, var, **kwargs)
#     542
#     543         bins, nbins, nsector, colors, angles, kwargs = self._init_plot(
# --> 544             direction, var, **kwargs
#     545         )
#     546         kwargs.pop("facecolor", None)
#
# ~\Anaconda3\envs\thesis\lib\site-packages\windrose\windrose.py in _init_plot(self, direction, var, **kwargs)
#     311         bins = kwargs.pop("bins", None)
#     312         if bins is None:
# --> 313             bins = np.linspace(np.min(var), np.max(var), 6)
#     314         if isinstance(bins, int):
#     315             bins = np.linspace(np.min(var), np.max(var), bins)
#
# ~\Anaconda3\envs\thesis\lib\site-packages\numpy\core\function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     133     # Convert float/complex array scalars to float, gh-3504
#     134     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 135     start = asanyarray(start) * 1.0
#     136     stop  = asanyarray(stop)  * 1.0
#     137
#
# TypeError: ufunc 'multiply' did not contain a loop with signature matching types dtype('<U32') dtype('<U32') dtype('<U32')
