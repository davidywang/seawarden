# %%
#aerialImageRetrieval commandline in python
#%run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping
from aerialImageRetrieval_2 import AerialImageRetrieval

#load csv containing coordinates of polygon corners
f = '/Users/Zack/0_seawarden/python/detection/d1_targets/'
file = f + 'g25_100m_10-20_01-06_v2.csv'

#load centroids to include in filename
centroids = gpd.read_file(f + 'g25_100m_10-20_01-06_v2.geojson')

targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))
targets.head()

topleft = targets.drop(targets.index[0])
topleft = topleft.iloc[::5]
print(len(topleft))

bright = targets.drop(targets.index[0:3])
bright = bright.iloc[::5] 
print(len(bright))

# create lists
lat1_list=topleft['y'].tolist()
lon1_list=topleft['x'].tolist()
lat2_list=bright['y'].tolist()
lon2_list=bright['x'].tolist()
# Out:
# 16865
# 3373
# 3373

# %%
for i in range(1000,2000):
    lat1=round(lat1_list[i],5)
    lon1=round(lon1_list[i],5)
    lat2=round(lat2_list[i],5)
    lon2=round(lon2_list[i],5)
    
    xy = mapping(centroids.geometry[i])['coordinates']
    x = round(xy[0], 5)
    y = round(xy[1], 5)

    imgretrieval = AerialImageRetrieval(x, y, lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print(lat1, lon1, lat2, lon2, "Retrieved image with maximum resolution.")
    else:
        print(lat1, lon1, lat2, lon2, "Cannot retrieve the desired image.")
# Out:
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170885, 814396)
# Cannot find tile image at level 20 for tile coordinate (585442, 407198)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.25616 20.99704 37.25703 20.99588 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170889, 814391)
# Cannot find tile image at level 20 for tile coordinate (585444, 407195)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.25686 20.99758 37.25774 20.99642 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170882, 814387)
# Cannot find tile image at level 20 for tile coordinate (585441, 407193)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.25735 20.99641 37.25822 20.99525 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190503, 814075)
# Cannot find tile image at level 20 for tile coordinate (595251, 407037)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.29999 24.36463 37.30089 24.36351 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203185, 814254)
# Cannot find tile image at level 20 for tile coordinate (601592, 407127)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.27553 26.54159 37.27646 26.54049 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183391, 814076)
# Cannot find tile image at level 20 for tile coordinate (591695, 407038)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.29985 23.14376 37.30074 23.14262 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183396, 814054)
# Cannot find tile image at level 20 for tile coordinate (591698, 407027)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.30292 23.14454 37.30382 23.1434 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204389, 814261)
# Cannot find tile image at level 20 for tile coordinate (602194, 407130)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.27456 26.74818 37.27549 26.74709 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1191427, 814034)
# Cannot find tile image at level 20 for tile coordinate (595713, 407017)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.30555 24.52316 37.30646 24.52204 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204502, 814257)
# Cannot find tile image at level 20 for tile coordinate (602251, 407128)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.27505 26.76758 37.27597 26.76648 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183739, 814031)
# Cannot find tile image at level 20 for tile coordinate (591869, 407015)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.306 23.20342 37.30689 23.20229 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204561, 814246)
# Cannot find tile image at level 20 for tile coordinate (602280, 407123)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.27657 26.77769 37.27749 26.7766 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204514, 814239)
# Cannot find tile image at level 20 for tile coordinate (602257, 407119)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.27752 26.76975 37.27844 26.76866 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183737, 814021)
# Cannot find tile image at level 20 for tile coordinate (591868, 407010)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.30741 23.2032 37.3083 23.20206 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203206, 814192)
# Cannot find tile image at level 20 for tile coordinate (601603, 407096)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.28396 26.54527 37.28488 26.54417 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204541, 814224)
# Cannot find tile image at level 20 for tile coordinate (602270, 407112)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.27958 26.77436 37.28051 26.77327 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185119, 813996)
# Cannot find tile image at level 20 for tile coordinate (592559, 406998)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.31079 23.44037 37.31168 23.43923 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184771, 813982)
# Cannot find tile image at level 20 for tile coordinate (592385, 406991)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.31271 23.38066 37.3136 23.37952 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204472, 814200)
# Cannot find tile image at level 20 for tile coordinate (602236, 407100)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.28289 26.76249 37.28382 26.76139 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203402, 814150)
# Cannot find tile image at level 20 for tile coordinate (601701, 407075)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.28974 26.57888 37.29067 26.57779 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183356, 813958)
# Cannot find tile image at level 20 for tile coordinate (591678, 406979)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.31599 23.13778 37.31689 23.13664 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203096, 814119)
# Cannot find tile image at level 20 for tile coordinate (601548, 407059)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.2939 26.52632 37.29482 26.52522 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190853, 813920)
# Cannot find tile image at level 20 for tile coordinate (595426, 406960)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3211 24.42469 37.322 24.42357 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183390, 813967)
# Cannot find tile image at level 20 for tile coordinate (591695, 406983)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.31468 23.1436 37.31557 23.14246 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183455, 813926)
# Cannot find tile image at level 20 for tile coordinate (591727, 406963)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32035 23.1548 37.32124 23.15366 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190802, 813907)
# Cannot find tile image at level 20 for tile coordinate (595401, 406953)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32288 24.41592 37.32379 24.4148 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170923, 814173)
# Cannot find tile image at level 20 for tile coordinate (585461, 407086)
# Cannot find tile image at level 19 for tile coordinate (292730, 203543)
# Cannot find tile image at level 18 for tile coordinate (146365, 101771)
# Cannot find tile image at level 17 for tile coordinate (73182, 50885)
# Finish the aerial image retrieval, store the image image_16.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.28657 21.00354 37.28744 21.00238 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183612, 813900)
# Cannot find tile image at level 20 for tile coordinate (591806, 406950)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3239 23.18164 37.32479 23.18051 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183435, 813898)
# Cannot find tile image at level 20 for tile coordinate (591717, 406949)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32415 23.15131 37.32504 23.15017 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183418, 813895)
# Cannot find tile image at level 20 for tile coordinate (591709, 406947)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32455 23.14842 37.32544 23.14728 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183414, 813895)
# Cannot find tile image at level 20 for tile coordinate (591707, 406947)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3246 23.14768 37.32549 23.14655 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183429, 813900)
# Cannot find tile image at level 20 for tile coordinate (591714, 406950)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32384 23.15029 37.32474 23.14915 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190516, 813967)
# Cannot find tile image at level 20 for tile coordinate (595258, 406983)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.31472 24.36684 37.31563 24.36572 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183223, 813892)
# Cannot find tile image at level 20 for tile coordinate (591611, 406946)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32501 23.11485 37.32591 23.11371 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183424, 813887)
# Cannot find tile image at level 20 for tile coordinate (591712, 406943)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32567 23.14936 37.32656 23.14822 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1181499, 813905)
# Cannot find tile image at level 20 for tile coordinate (590749, 406952)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32322 22.81895 37.32411 22.81781 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1181532, 813908)
# Cannot find tile image at level 20 for tile coordinate (590766, 406954)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32274 22.82469 37.32363 22.82355 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185010, 813864)
# Cannot find tile image at level 20 for tile coordinate (592505, 406932)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32875 23.42161 37.32964 23.42047 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184881, 813861)
# Cannot find tile image at level 20 for tile coordinate (592440, 406930)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32914 23.3995 37.33004 23.39836 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203546, 814059)
# Cannot find tile image at level 20 for tile coordinate (601773, 407029)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.30208 26.60354 37.30301 26.60245 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190536, 813836)
# Cannot find tile image at level 20 for tile coordinate (595268, 406918)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.33266 24.37023 37.33357 24.36911 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183318, 813849)
# Cannot find tile image at level 20 for tile coordinate (591659, 406924)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.33091 23.1313 37.3318 23.13016 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183279, 813836)
# Cannot find tile image at level 20 for tile coordinate (591639, 406918)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.33268 23.12446 37.33357 23.12332 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185040, 813814)
# Cannot find tile image at level 20 for tile coordinate (592520, 406907)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.33557 23.42679 37.33647 23.42566 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204685, 814010)
# Cannot find tile image at level 20 for tile coordinate (602342, 407005)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.30883 26.79903 37.30975 26.79794 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203130, 813935)
# Cannot find tile image at level 20 for tile coordinate (601565, 406967)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.31907 26.5322 37.31999 26.53111 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183921, 813748)
# Cannot find tile image at level 20 for tile coordinate (591960, 406874)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34466 23.23474 37.34555 23.2336 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183943, 813746)
# Cannot find tile image at level 20 for tile coordinate (591971, 406873)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34495 23.23853 37.34585 23.2374 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184403, 813741)
# Cannot find tile image at level 20 for tile coordinate (592201, 406870)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34565 23.31751 37.34655 23.31637 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185139, 813731)
# Cannot find tile image at level 20 for tile coordinate (592569, 406865)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34689 23.44375 37.34779 23.44262 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185186, 813716)
# Cannot find tile image at level 20 for tile coordinate (592593, 406858)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34902 23.45196 37.34991 23.45082 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203554, 813905)
# Cannot find tile image at level 20 for tile coordinate (601777, 406952)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.32312 26.60485 37.32405 26.60376 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1182969, 813707)
# Cannot find tile image at level 20 for tile coordinate (591484, 406853)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.35017 23.07127 37.35106 23.07013 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183124, 813699)
# Cannot find tile image at level 20 for tile coordinate (591562, 406849)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.35136 23.09796 37.35225 23.09682 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1181390, 813712)
# Cannot find tile image at level 20 for tile coordinate (590695, 406856)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34959 22.80033 37.35048 22.79919 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1181390, 813701)
# Cannot find tile image at level 20 for tile coordinate (590695, 406850)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.35111 22.80021 37.352 22.79906 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185693, 813612)
# Cannot find tile image at level 20 for tile coordinate (592846, 406806)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3632 23.53886 37.36409 23.53773 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183912, 813610)
# Cannot find tile image at level 20 for tile coordinate (591956, 406805)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.36352 23.23322 37.36441 23.23208 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203495, 813779)
# Cannot find tile image at level 20 for tile coordinate (601747, 406889)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34037 26.59471 37.3413 26.59361 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1182978, 813593)
# Cannot find tile image at level 20 for tile coordinate (591489, 406796)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.36583 23.07283 37.36672 23.07169 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204268, 813796)
# Cannot find tile image at level 20 for tile coordinate (602134, 406898)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.33801 26.72747 37.33894 26.72638 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204257, 813784)
# Cannot find tile image at level 20 for tile coordinate (602128, 406892)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.33962 26.72552 37.34055 26.72442 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203147, 813731)
# Cannot find tile image at level 20 for tile coordinate (601573, 406865)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.34697 26.53507 37.34789 26.53397 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190645, 813460)
# Cannot find tile image at level 20 for tile coordinate (595322, 406730)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.38387 24.38898 37.38477 24.38786 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184010, 813441)
# Cannot find tile image at level 20 for tile coordinate (592005, 406720)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.38657 23.24997 37.38746 23.24883 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203131, 813609)
# Cannot find tile image at level 20 for tile coordinate (601565, 406804)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.36357 26.53227 37.3645 26.53117 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204385, 813640)
# Cannot find tile image at level 20 for tile coordinate (602192, 406820)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3594 26.74749 37.36033 26.7464 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1182919, 813430)
# Cannot find tile image at level 20 for tile coordinate (591459, 406715)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.38801 23.06276 37.3889 23.06161 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1182919, 813428)
# Cannot find tile image at level 20 for tile coordinate (591459, 406714)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.38833 23.06265 37.38922 23.06151 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203728, 813607)
# Cannot find tile image at level 20 for tile coordinate (601864, 406803)
# Cannot find tile image at level 19 for tile coordinate (300932, 203401)
# Cannot find tile image at level 18 for tile coordinate (150466, 101700)
# Cannot find tile image at level 17 for tile coordinate (75233, 50850)
# Finish the aerial image retrieval, store the image image_16.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.36391 26.63471 37.36483 26.63362 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190641, 813389)
# Cannot find tile image at level 20 for tile coordinate (595320, 406694)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3936 24.38822 37.3945 24.3871 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1193522, 813397)
# Cannot find tile image at level 20 for tile coordinate (596761, 406698)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.39248 24.88282 37.39339 24.8817 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1193984, 813393)
# Cannot find tile image at level 20 for tile coordinate (596992, 406696)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.393 24.96209 37.39391 24.96097 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1203281, 813562)
# Cannot find tile image at level 20 for tile coordinate (601640, 406781)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.37002 26.55802 37.37095 26.55692 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204101, 813559)
# Cannot find tile image at level 20 for tile coordinate (602050, 406779)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.37032 26.69881 37.37125 26.69771 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184106, 813339)
# Cannot find tile image at level 20 for tile coordinate (592053, 406669)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.40042 23.26644 37.40131 23.2653 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1195746, 813357)
# Cannot find tile image at level 20 for tile coordinate (597873, 406678)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.39793 25.26464 37.39884 25.26353 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204352, 813537)
# Cannot find tile image at level 20 for tile coordinate (602176, 406768)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.37335 26.74193 37.37428 26.74084 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1191238, 813384)
# Cannot find tile image at level 20 for tile coordinate (595619, 406692)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.39422 24.49082 37.39512 24.48969 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1193470, 813400)
# Cannot find tile image at level 20 for tile coordinate (596735, 406700)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.39213 24.87392 37.39304 24.8728 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1193444, 813399)
# Cannot find tile image at level 20 for tile coordinate (596722, 406699)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.3922 24.86942 37.39311 24.8683 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1204213, 813517)
# Cannot find tile image at level 20 for tile coordinate (602106, 406758)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.37614 26.71807 37.37706 26.71697 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1196243, 813327)
# Cannot find tile image at level 20 for tile coordinate (598121, 406663)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.40202 25.34989 37.40294 25.34878 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1193371, 813276)
# Cannot find tile image at level 20 for tile coordinate (596685, 406638)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.40898 24.85699 37.40989 24.85587 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190616, 813243)
# Cannot find tile image at level 20 for tile coordinate (595308, 406621)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.4135 24.38404 37.4144 24.38292 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183342, 813261)
# Cannot find tile image at level 20 for tile coordinate (591671, 406630)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.41113 23.13531 37.41202 23.13417 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183333, 813257)
# Cannot find tile image at level 20 for tile coordinate (591666, 406628)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.41165 23.13385 37.41254 23.13271 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1196132, 813286)
# Cannot find tile image at level 20 for tile coordinate (598066, 406643)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.40768 25.33079 37.40859 25.32968 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183317, 813253)
# Cannot find tile image at level 20 for tile coordinate (591658, 406626)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.41218 23.13102 37.41308 23.12988 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1183318, 813247)
# Cannot find tile image at level 20 for tile coordinate (591659, 406623)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.41301 23.13116 37.41391 23.13002 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1190497, 813217)
# Cannot find tile image at level 20 for tile coordinate (595248, 406608)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.41712 24.3635 37.41802 24.36237 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1181201, 813243)
# Cannot find tile image at level 20 for tile coordinate (590600, 406621)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.41348 22.76789 37.41437 22.76675 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# ...
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169060, 805553)
# Cannot find tile image at level 20 for tile coordinate (584530, 402776)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.45474 20.68378 38.4556 20.6826 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168456, 805574)
# Cannot find tile image at level 20 for tile coordinate (584228, 402787)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.45182 20.58009 38.45269 20.57891 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171207, 805430)
# Cannot find tile image at level 20 for tile coordinate (585603, 402715)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47122 21.05225 38.47209 21.05107 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200898, 805286)
# Cannot find tile image at level 20 for tile coordinate (600449, 402643)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49048 26.14898 38.49141 26.14787 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171493, 805415)
# Cannot find tile image at level 20 for tile coordinate (585746, 402707)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47323 21.10132 38.4741 21.10014 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171221, 805423)
# Cannot find tile image at level 20 for tile coordinate (585610, 402711)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47214 21.05476 38.47301 21.05358 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186229, 805137)
# Cannot find tile image at level 20 for tile coordinate (593114, 402568)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51048 23.63086 38.51138 23.62971 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186249, 805132)
# Cannot find tile image at level 20 for tile coordinate (593124, 402566)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51118 23.63431 38.51208 23.63316 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171500, 805395)
# Cannot find tile image at level 20 for tile coordinate (585750, 402697)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47591 21.10256 38.47678 21.10138 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186237, 805133)
# Cannot find tile image at level 20 for tile coordinate (593118, 402566)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51101 23.63228 38.51191 23.63113 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184475, 805136)
# Cannot find tile image at level 20 for tile coordinate (592237, 402568)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.5107 23.32977 38.5116 23.32862 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171486, 805385)
# Cannot find tile image at level 20 for tile coordinate (585743, 402692)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47728 21.10009 38.47815 21.09891 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201678, 805277)
# Cannot find tile image at level 20 for tile coordinate (600839, 402638)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49168 26.28285 38.4926 26.28173 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200952, 805257)
# Cannot find tile image at level 20 for tile coordinate (600476, 402628)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49445 26.15819 38.49537 26.15708 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201587, 805256)
# Cannot find tile image at level 20 for tile coordinate (600793, 402628)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.4945 26.26726 38.49543 26.26614 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1189752, 805089)
# Cannot find tile image at level 20 for tile coordinate (594876, 402544)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.517 24.2357 38.51791 24.23456 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201642, 805248)
# Cannot find tile image at level 20 for tile coordinate (600821, 402624)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49558 26.27669 38.49651 26.27557 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169762, 805405)
# Cannot find tile image at level 20 for tile coordinate (584881, 402702)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47456 20.80423 38.47542 20.80304 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184584, 805089)
# Cannot find tile image at level 20 for tile coordinate (592292, 402544)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51695 23.34849 38.51785 23.34733 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201602, 805237)
# Cannot find tile image at level 20 for tile coordinate (600801, 402618)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49702 26.26989 38.49794 26.26878 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171095, 805354)
# Cannot find tile image at level 20 for tile coordinate (585547, 402677)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48145 21.03311 38.48232 21.03193 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201600, 805238)
# Cannot find tile image at level 20 for tile coordinate (600800, 402619)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49689 26.26959 38.49781 26.26847 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171093, 805351)
# Cannot find tile image at level 20 for tile coordinate (585546, 402675)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48177 21.03271 38.48264 21.03153 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201604, 805235)
# Cannot find tile image at level 20 for tile coordinate (600802, 402617)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49738 26.27022 38.4983 26.2691 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184588, 805082)
# Cannot find tile image at level 20 for tile coordinate (592294, 402541)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51787 23.34927 38.51877 23.34812 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171457, 805338)
# Cannot find tile image at level 20 for tile coordinate (585728, 402669)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48353 21.09527 38.4844 21.09409 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184583, 805080)
# Cannot find tile image at level 20 for tile coordinate (592291, 402540)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51823 23.34831 38.51913 23.34716 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169821, 805385)
# Cannot find tile image at level 20 for tile coordinate (584910, 402692)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47727 20.81433 38.47814 20.81315 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168669, 805413)
# Cannot find tile image at level 20 for tile coordinate (584334, 402706)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.47343 20.61662 38.47429 20.61544 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201575, 805199)
# Cannot find tile image at level 20 for tile coordinate (600787, 402599)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.5022 26.26514 38.50313 26.26402 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171416, 805305)
# Cannot find tile image at level 20 for tile coordinate (585708, 402652)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48794 21.08823 38.48881 21.08705 Retrieved image with maximum resolution.

# %%
#add farm ID to filename (quick fix)
#import os 

#folder = "/Users/Zack/0_thesis_bing/images_2019-10-13/"
#files = os.listdir(folder)
#print(files)

#sort files by date: newest to oldest
# search_dir = folder
# os.chdir(search_dir)
# files = filter(os.path.isfile, os.listdir(search_dir))
# files = [os.path.join(f) for f in files] 
# files.sort(key=lambda x: os.path.getmtime(x))
# print(len(files))

# #rename with farm ID
# for index, i in enumerate(files):
#     org = (i[11:])
#     name = (str(index))
#     dst = (name + org)
#     src = (i)
#     os.rename(src, dst)
