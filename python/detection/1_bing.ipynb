# %%
#aerialImageRetrieval commandline in python
#%run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping
from aerialImageRetrieval_2 import AerialImageRetrieval

#load csv containing coordinates of polygon corners
file = '/Users/Zack/0_seawarden/python/detection/g25_100m_10-20_01-06_100m.csv'

#load centroids to include in filename
centroids = gpd.read_file('/Users/Zack/0_GIS_Greece/sar_tests_greece/g25_100m_10-20_01-06.geojson')

targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))
targets.head()

topleft = targets.drop(targets.index[0])
topleft = topleft.iloc[::5]
print(len(topleft))

bright = targets.drop(targets.index[0:3])
bright = bright.iloc[::5] 
print(len(bright))

# create lists
lat1_list=topleft['y'].tolist()
lon1_list=topleft['x'].tolist()
lat2_list=bright['y'].tolist()
lon2_list=bright['x'].tolist()
# Out:
# 16850
# 3370
# 3370

# %%
for i in range(2000,4000):
    lat1=round(lat1_list[i],5)
    lon1=round(lon1_list[i],5)
    lat2=round(lat2_list[i],5)
    lon2=round(lon2_list[i],5)
    
    xy = mapping(centroids.geometry[i])['coordinates']
    x = round(xy[0], 5)
    y = round(xy[1], 5)

    imgretrieval = AerialImageRetrieval(x, y, lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print(lat1, lon1, lat2, lon2, "Retrieved image with maximum resolution.")
    else:
        print(lat1, lon1, lat2, lon2, "Cannot retrieve the desired image.")
# Out:
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201390, 805153)
# Cannot find tile image at level 20 for tile coordinate (600695, 402576)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.50836 26.23346 38.50929 26.23234 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168883, 805343)
# Cannot find tile image at level 20 for tile coordinate (584441, 402671)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48285 20.65332 38.48371 20.65214 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197256, 805056)
# Cannot find tile image at level 20 for tile coordinate (598628, 402528)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.52139 25.52387 38.5223 25.52274 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201636, 805141)
# Cannot find tile image at level 20 for tile coordinate (600818, 402570)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.50992 26.27578 38.51084 26.27466 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1199140, 805081)
# Cannot find tile image at level 20 for tile coordinate (599570, 402540)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51808 25.84727 38.519 25.84615 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201340, 805129)
# Cannot find tile image at level 20 for tile coordinate (600670, 402564)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51161 26.22494 38.51253 26.22382 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201647, 805127)
# Cannot find tile image at level 20 for tile coordinate (600823, 402563)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.51189 26.27753 38.51281 26.27641 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184700, 804951)
# Cannot find tile image at level 20 for tile coordinate (592350, 402475)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53556 23.36852 38.53645 23.36737 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168875, 805291)
# Cannot find tile image at level 20 for tile coordinate (584437, 402645)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48984 20.65204 38.49071 20.65086 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168003, 805324)
# Cannot find tile image at level 20 for tile coordinate (584001, 402662)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48546 20.50232 38.48632 20.50113 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186200, 804935)
# Cannot find tile image at level 20 for tile coordinate (593100, 402467)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53767 23.62603 38.53857 23.62488 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197149, 804999)
# Cannot find tile image at level 20 for tile coordinate (598574, 402499)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.52901 25.50552 38.52993 25.5044 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170083, 805233)
# Cannot find tile image at level 20 for tile coordinate (585041, 402616)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49766 20.85938 38.49853 20.85819 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184655, 804930)
# Cannot find tile image at level 20 for tile coordinate (592327, 402465)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.5383 23.36081 38.53919 23.35965 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197188, 804989)
# Cannot find tile image at level 20 for tile coordinate (598594, 402494)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53035 25.51221 38.53127 25.51108 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197096, 804970)
# Cannot find tile image at level 20 for tile coordinate (598548, 402485)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.533 25.49632 38.53392 25.4952 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197486, 804976)
# Cannot find tile image at level 20 for tile coordinate (598743, 402488)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53214 25.56323 38.53306 25.56211 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197098, 804969)
# Cannot find tile image at level 20 for tile coordinate (598549, 402484)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53303 25.49677 38.53395 25.49564 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201602, 805050)
# Cannot find tile image at level 20 for tile coordinate (600801, 402525)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.52226 26.26983 38.52318 26.26872 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197607, 804962)
# Cannot find tile image at level 20 for tile coordinate (598803, 402481)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53408 25.58416 38.535 25.58303 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184474, 804893)
# Cannot find tile image at level 20 for tile coordinate (592237, 402446)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.54324 23.32963 38.54414 23.32847 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197600, 804952)
# Cannot find tile image at level 20 for tile coordinate (598800, 402476)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53533 25.58288 38.53625 25.58175 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201472, 805013)
# Cannot find tile image at level 20 for tile coordinate (600736, 402506)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.52717 26.24746 38.52809 26.24634 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197511, 804929)
# Cannot find tile image at level 20 for tile coordinate (598755, 402464)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53852 25.56756 38.53943 25.56643 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197559, 804919)
# Cannot find tile image at level 20 for tile coordinate (598779, 402459)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53981 25.57578 38.54073 25.57465 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201157, 804977)
# Cannot find tile image at level 20 for tile coordinate (600578, 402488)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53207 26.19346 38.53299 26.19234 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197139, 804890)
# Cannot find tile image at level 20 for tile coordinate (598569, 402445)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.54369 25.50378 38.54461 25.50265 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184450, 804829)
# Cannot find tile image at level 20 for tile coordinate (592225, 402414)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55196 23.32555 38.55285 23.3244 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197134, 804987)
# Cannot find tile image at level 20 for tile coordinate (598567, 402493)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53065 25.50282 38.53157 25.5017 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184613, 804928)
# Cannot find tile image at level 20 for tile coordinate (592307, 402464)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53864 23.35362 38.53954 23.35247 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184584, 804928)
# Cannot find tile image at level 20 for tile coordinate (592292, 402464)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53866 23.34851 38.53956 23.34736 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197070, 804985)
# Cannot find tile image at level 20 for tile coordinate (598535, 402492)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53093 25.49188 38.53185 25.49075 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184603, 804928)
# Cannot find tile image at level 20 for tile coordinate (592301, 402464)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53866 23.35182 38.53955 23.35066 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197153, 804877)
# Cannot find tile image at level 20 for tile coordinate (598576, 402438)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.5454 25.50617 38.54632 25.50504 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186079, 804769)
# Cannot find tile image at level 20 for tile coordinate (593039, 402384)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55995 23.60523 38.56085 23.60408 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184418, 804775)
# Cannot find tile image at level 20 for tile coordinate (592209, 402387)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55911 23.31998 38.56001 23.31883 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201151, 804908)
# Cannot find tile image at level 20 for tile coordinate (600575, 402454)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.5412 26.19243 38.54213 26.19131 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201185, 804907)
# Cannot find tile image at level 20 for tile coordinate (600592, 402453)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.54145 26.19825 38.54238 26.19713 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184410, 804766)
# Cannot find tile image at level 20 for tile coordinate (592205, 402383)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56042 23.31876 38.56132 23.31761 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197455, 804835)
# Cannot find tile image at level 20 for tile coordinate (598727, 402417)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55103 25.558 38.55195 25.55687 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186072, 804763)
# Cannot find tile image at level 20 for tile coordinate (593036, 402381)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56076 23.60405 38.56166 23.6029 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197479, 804821)
# Cannot find tile image at level 20 for tile coordinate (598739, 402410)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55301 25.56206 38.55392 25.56093 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186047, 804735)
# Cannot find tile image at level 20 for tile coordinate (593023, 402367)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56448 23.59973 38.56538 23.59857 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184415, 804733)
# Cannot find tile image at level 20 for tile coordinate (592207, 402366)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56484 23.3196 38.56574 23.31844 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197442, 804791)
# Cannot find tile image at level 20 for tile coordinate (598721, 402395)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55702 25.55583 38.55794 25.5547 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184409, 804728)
# Cannot find tile image at level 20 for tile coordinate (592204, 402364)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56546 23.31859 38.56635 23.31743 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197438, 804787)
# Cannot find tile image at level 20 for tile coordinate (598719, 402393)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55757 25.55508 38.55849 25.55395 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171384, 804977)
# Cannot find tile image at level 20 for tile coordinate (585692, 402488)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53209 21.08264 38.53297 21.08145 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184379, 804707)
# Cannot find tile image at level 20 for tile coordinate (592189, 402353)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56823 23.31341 38.56913 23.31225 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197474, 804745)
# Cannot find tile image at level 20 for tile coordinate (598737, 402372)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56319 25.56122 38.5641 25.56009 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170972, 804933)
# Cannot find tile image at level 20 for tile coordinate (585486, 402466)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.53792 21.01187 38.53879 21.01069 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185655, 804650)
# Cannot find tile image at level 20 for tile coordinate (592827, 402325)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.57586 23.53244 38.57676 23.53129 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200570, 804776)
# Cannot find tile image at level 20 for tile coordinate (600285, 402388)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55904 26.09276 38.55996 26.09164 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200803, 804767)
# Cannot find tile image at level 20 for tile coordinate (600401, 402383)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56022 26.13274 38.56114 26.13162 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170961, 804900)
# Cannot find tile image at level 20 for tile coordinate (585480, 402450)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.54236 21.0101 38.54323 21.00892 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200806, 804755)
# Cannot find tile image at level 20 for tile coordinate (600403, 402377)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56185 26.13317 38.56277 26.13205 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170956, 804892)
# Cannot find tile image at level 20 for tile coordinate (585478, 402446)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.54341 21.00916 38.54429 21.00798 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170302, 804912)
# Cannot find tile image at level 20 for tile coordinate (585151, 402456)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.54075 20.89698 38.54162 20.89579 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184349, 804607)
# Cannot find tile image at level 20 for tile coordinate (592174, 402303)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58167 23.30818 38.58256 23.30702 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184354, 804605)
# Cannot find tile image at level 20 for tile coordinate (592177, 402302)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58195 23.30911 38.58284 23.30795 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200879, 804731)
# Cannot find tile image at level 20 for tile coordinate (600439, 402365)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56501 26.14571 38.56593 26.14459 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1199149, 804688)
# Cannot find tile image at level 20 for tile coordinate (599574, 402344)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.57078 25.84874 38.5717 25.84761 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184349, 804582)
# Cannot find tile image at level 20 for tile coordinate (592174, 402291)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58505 23.30818 38.58594 23.30702 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184388, 804578)
# Cannot find tile image at level 20 for tile coordinate (592194, 402289)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58565 23.31491 38.58655 23.31376 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184364, 804601)
# Cannot find tile image at level 20 for tile coordinate (592182, 402300)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58248 23.31071 38.58337 23.30956 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184380, 804573)
# Cannot find tile image at level 20 for tile coordinate (592190, 402286)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58626 23.31354 38.58716 23.31238 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184389, 804566)
# Cannot find tile image at level 20 for tile coordinate (592194, 402283)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.58721 23.31501 38.58811 23.31385 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197369, 804622)
# Cannot find tile image at level 20 for tile coordinate (598684, 402311)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.57962 25.54322 38.58054 25.54209 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184391, 804561)
# Cannot find tile image at level 20 for tile coordinate (592195, 402280)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.5879 23.31547 38.58879 23.31431 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170988, 804814)
# Cannot find tile image at level 20 for tile coordinate (585494, 402407)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55394 21.01473 38.55481 21.01355 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1189196, 804521)
# Cannot find tile image at level 20 for tile coordinate (594598, 402260)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59326 24.14019 38.59417 24.13905 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170984, 804801)
# Cannot find tile image at level 20 for tile coordinate (585492, 402400)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.55572 21.01404 38.55659 21.01286 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184529, 804471)
# Cannot find tile image at level 20 for tile coordinate (592264, 402235)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59992 23.33912 38.60082 23.33796 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184531, 804465)
# Cannot find tile image at level 20 for tile coordinate (592265, 402232)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60079 23.33951 38.60169 23.33835 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197768, 804528)
# Cannot find tile image at level 20 for tile coordinate (598884, 402264)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59224 25.61169 38.59315 25.61056 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184541, 804450)
# Cannot find tile image at level 20 for tile coordinate (592270, 402225)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60282 23.34111 38.60372 23.33996 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184535, 804459)
# Cannot find tile image at level 20 for tile coordinate (592267, 402229)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60162 23.34012 38.60251 23.33896 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197276, 804499)
# Cannot find tile image at level 20 for tile coordinate (598638, 402249)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59613 25.52721 38.59705 25.52608 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1199759, 804538)
# Cannot find tile image at level 20 for tile coordinate (599879, 402269)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59096 25.95341 38.59188 25.95229 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197412, 804489)
# Cannot find tile image at level 20 for tile coordinate (598706, 402244)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59756 25.55068 38.59848 25.54955 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197317, 804491)
# Cannot find tile image at level 20 for tile coordinate (598658, 402245)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59721 25.53429 38.59812 25.53316 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197695, 804478)
# Cannot find tile image at level 20 for tile coordinate (598847, 402239)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59904 25.59924 38.59996 25.59811 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1200374, 804530)
# Cannot find tile image at level 20 for tile coordinate (600187, 402265)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59203 26.05904 38.59295 26.05792 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197711, 804470)
# Cannot find tile image at level 20 for tile coordinate (598855, 402235)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.6 25.602 38.60091 25.60087 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184539, 804402)
# Cannot find tile image at level 20 for tile coordinate (592269, 402201)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.6092 23.34091 38.6101 23.33975 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1199839, 804510)
# Cannot find tile image at level 20 for tile coordinate (599919, 402255)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59474 25.96718 38.59566 25.96606 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197362, 804458)
# Cannot find tile image at level 20 for tile coordinate (598681, 402229)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60164 25.54199 38.60256 25.54087 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168265, 804758)
# Cannot find tile image at level 20 for tile coordinate (584132, 402379)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.56153 20.5472 38.56239 20.54601 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197520, 804450)
# Cannot find tile image at level 20 for tile coordinate (598760, 402225)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60277 25.5692 38.60369 25.56807 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197680, 804447)
# Cannot find tile image at level 20 for tile coordinate (598840, 402223)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60312 25.59654 38.60404 25.59541 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197613, 804443)
# Cannot find tile image at level 20 for tile coordinate (598806, 402221)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60374 25.58519 38.60466 25.58406 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1199971, 804487)
# Cannot find tile image at level 20 for tile coordinate (599985, 402243)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.59779 25.98988 38.59871 25.98876 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1197611, 804420)
# Cannot find tile image at level 20 for tile coordinate (598805, 402210)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.60675 25.58475 38.60767 25.58362 Retrieved image with maximum resolution.
# ...
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.68411 24.03842 38.68502 24.03727 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168328, 804217)
# Cannot find tile image at level 20 for tile coordinate (584164, 402108)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.63398 20.558 38.63485 20.55681 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1185056, 803849)
# Cannot find tile image at level 20 for tile coordinate (592528, 401924)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.68329 23.4296 38.68418 23.42844 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168327, 804168)
# Cannot find tile image at level 20 for tile coordinate (584163, 402084)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.64062 20.55785 38.64149 20.55666 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168324, 804156)
# Cannot find tile image at level 20 for tile coordinate (584162, 402078)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.64217 20.55742 38.64304 20.55623 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184938, 803785)
# Cannot find tile image at level 20 for tile coordinate (592469, 401892)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.69192 23.40937 38.69282 23.40822 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1182954, 803763)
# Cannot find tile image at level 20 for tile coordinate (591477, 401881)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.69491 23.06878 38.69581 23.06762 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169734, 804005)
# Cannot find tile image at level 20 for tile coordinate (584867, 402002)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.66251 20.79934 38.66337 20.79815 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170610, 803968)
# Cannot find tile image at level 20 for tile coordinate (585305, 401984)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.66736 20.94975 38.66823 20.94856 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184740, 803666)
# Cannot find tile image at level 20 for tile coordinate (592370, 401833)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.70789 23.37541 38.70879 23.37425 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169684, 803982)
# Cannot find tile image at level 20 for tile coordinate (584842, 401991)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.66552 20.79086 38.66639 20.78967 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169698, 803965)
# Cannot find tile image at level 20 for tile coordinate (584849, 401982)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.66778 20.79319 38.66865 20.792 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1170485, 803934)
# Cannot find tile image at level 20 for tile coordinate (585242, 401967)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.67195 20.92834 38.67282 20.92715 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169685, 803951)
# Cannot find tile image at level 20 for tile coordinate (584842, 401975)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.66968 20.79096 38.67055 20.78977 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169664, 803931)
# Cannot find tile image at level 20 for tile coordinate (584832, 401965)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.67244 20.78734 38.67331 20.78616 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169161, 803847)
# Cannot find tile image at level 20 for tile coordinate (584580, 401923)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.68358 20.70101 38.68445 20.69982 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169188, 803834)
# Cannot find tile image at level 20 for tile coordinate (584594, 401917)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.68545 20.70575 38.68631 20.70457 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169433, 803816)
# Cannot find tile image at level 20 for tile coordinate (584716, 401908)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.68783 20.74779 38.6887 20.7466 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169433, 803713)
# Cannot find tile image at level 20 for tile coordinate (584716, 401856)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.70154 20.74777 38.70241 20.74658 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169232, 803709)
# Cannot find tile image at level 20 for tile coordinate (584616, 401854)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.70209 20.71327 38.70296 20.71209 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1184928, 803789)
# Cannot find tile image at level 20 for tile coordinate (592464, 401894)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.69141 23.4076 38.6923 23.40645 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201600, 805238)
# Cannot find tile image at level 20 for tile coordinate (600800, 402619)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49689 26.26959 38.49781 26.26847 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1201602, 805237)
# Cannot find tile image at level 20 for tile coordinate (600801, 402618)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.49702 26.26989 38.49794 26.26878 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1171095, 805354)
# Cannot find tile image at level 20 for tile coordinate (585547, 402677)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.48145 21.03311 38.48232 21.03193 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186302, 803316)
# Cannot find tile image at level 20 for tile coordinate (593151, 401658)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.75478 23.64355 38.75568 23.64239 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186397, 803306)
# Cannot find tile image at level 20 for tile coordinate (593198, 401653)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.75605 23.65979 38.75694 23.65863 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168427, 803643)
# Cannot find tile image at level 20 for tile coordinate (584213, 401821)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.71095 20.57511 38.71182 20.57392 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1169706, 803571)
# Cannot find tile image at level 20 for tile coordinate (584853, 401785)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.72059 20.79457 38.72146 20.79338 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1168432, 803616)
# Cannot find tile image at level 20 for tile coordinate (584216, 401808)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.71458 20.57598 38.71545 20.57478 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186146, 803237)
# Cannot find tile image at level 20 for tile coordinate (593073, 401618)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.76526 23.61663 38.76615 23.61548 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186013, 803234)
# Cannot find tile image at level 20 for tile coordinate (593006, 401617)
# Finish the aerial image retrieval, store the image image_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 38.76566 23.59386 38.76655 23.59271 Retrieved image with maximum resolution.
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Cannot find tile image at level 21 for tile coordinate (1186664, 803213)
# Cannot find tile image at level 20 for tile coordinate (593332, 401606)

# %%
#add farm ID to filename (quick fix)
#import os 

#folder = "/Users/Zack/0_thesis_bing/images_2019-10-13/"
#files = os.listdir(folder)
#print(files)

#sort files by date: newest to oldest
# search_dir = folder
# os.chdir(search_dir)
# files = filter(os.path.isfile, os.listdir(search_dir))
# files = [os.path.join(f) for f in files] 
# files.sort(key=lambda x: os.path.getmtime(x))
# print(len(files))

# #rename with farm ID
# for index, i in enumerate(files):
#     org = (i[11:])
#     name = (str(index))
#     dst = (name + org)
#     src = (i)
#     os.rename(src, dst)
