# %%
#aerialImageRetrieval commandline in python
#%run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076
# Out:
# ERROR:root:File `'../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py'` not found.

# %%
import pandas as pd
from aerialImageRetrieval_2 import AerialImageRetrieval

#load csv containing coordinates of polygon corners
file = '/Users/Zack/Desktop/g25_100m_10-20_01-06_5m.csv'
targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))
targets.head()

topleft = targets.drop(targets.index[0])
topleft = topleft.iloc[::5]
print(len(topleft))
topleft.head()

bright = targets.drop(targets.index[0:3])
bright = bright.iloc[::5]
print(len(bright))
bright.head()

# create lists
lat1_list=topleft['y'].tolist()
lon1_list=topleft['x'].tolist()
lat2_list=bright['y'].tolist()
lon2_list=bright['x'].tolist()
# Out:
# 19185
# 3837
# 3837
#             x          y  id
# 3   24.112239  34.786359   0
# 8   24.048152  34.840457   1
# 13  24.118948  34.847133   2
# 18  24.043153  34.850801   3
# 23  24.038725  34.854059   4

# %%
#1308

# %%
#single location extractor
x=239
# lat1=topleft['y'].tolist()[x]
# lon1=topleft['x'].tolist()[x]
# lat2=bright['y'].tolist()[x]
# lon2=bright['x'].tolist()[x]

# print(topleft['y'].tolist()[x])
# print(topleft['x'].tolist()[x])
# print(bright['y'].tolist()[x])
# print(bright['x'].tolist()[x])

imgretrieval = AerialImageRetrieval(lat1_list[x], lon1_list[x], lat2_list[x], lon2_list[x])
if imgretrieval.max_resolution_imagery_retrieval():
    print("Successfully retrieved the image with maximum resolution!")
else:
    print("Cannot retrieve the desired image! (Possible reason: expected tile image does not exist.)")
# Out:
# 35.46900005965136
# 27.09827113115068
# 35.46904649096609
# 27.098217830525254
# Cannot find tile image at level 23 for tile coordinate (4825738, 3309328)
# Cannot find tile image at level 22 for tile coordinate (2412869, 1654664)
# Cannot find tile image at level 21 for tile coordinate (1206434, 827332)
# Cannot find tile image at level 20 for tile coordinate (603217, 413666)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# Successfully retrieved the image with maximum resolution!

# %%
for i in range(len(lat1_list)):
    lat1=round(lat1_list[i],5) #4
    lon1=round(lon1_list[i],5)
    lat2=round(lat2_list[i],5)
    lon2=round(lon2_list[i],5)
    print(lat1, lon1, lat2, lon2)
    
    imgretrieval = AerialImageRetrieval(lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print(lat1, lon1, lat2, lon2, "Successfully retrieved the image with maximum resolution!")
    else:
        print(lat1, lon1, lat2, lon2, "Cannot retrieve the desired image! (Possible reason: expected tile image does not exist.)")
# Out:
# 34.78631 24.11229 34.78636 24.11224
# Cannot find tile image at level 23 for tile coordinate (4756159, 3328778)
# Cannot find tile image at level 22 for tile coordinate (2378079, 1664389)
# Cannot find tile image at level 21 for tile coordinate (1189039, 832194)
# Cannot find tile image at level 20 for tile coordinate (594519, 416097)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.78631 24.11229 34.78636 24.11224 Successfully retrieved the image with maximum resolution!
# 34.84041 24.04821 34.84046 24.04815
# Cannot find tile image at level 23 for tile coordinate (4754666, 3327243)
# Cannot find tile image at level 22 for tile coordinate (2377333, 1663621)
# Cannot find tile image at level 21 for tile coordinate (1188666, 831810)
# Cannot find tile image at level 20 for tile coordinate (594333, 415905)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.84041 24.04821 34.84046 24.04815 Successfully retrieved the image with maximum resolution!
# 34.84709 24.119 34.84713 24.11895
# Cannot find tile image at level 23 for tile coordinate (4756316, 3327053)
# Cannot find tile image at level 22 for tile coordinate (2378158, 1663526)
# Cannot find tile image at level 21 for tile coordinate (1189079, 831763)
# Cannot find tile image at level 20 for tile coordinate (594539, 415881)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.84709 24.119 34.84713 24.11895 Successfully retrieved the image with maximum resolution!
# 34.85076 24.04321 34.8508 24.04315
# Cannot find tile image at level 23 for tile coordinate (4754550, 3326949)
# Cannot find tile image at level 22 for tile coordinate (2377275, 1663474)
# Cannot find tile image at level 21 for tile coordinate (1188637, 831737)
# Cannot find tile image at level 20 for tile coordinate (594318, 415868)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.85076 24.04321 34.8508 24.04315 Successfully retrieved the image with maximum resolution!
# 34.85401 24.03878 34.85406 24.03872
# Cannot find tile image at level 23 for tile coordinate (4754446, 3326857)
# Cannot find tile image at level 22 for tile coordinate (2377223, 1663428)
# Cannot find tile image at level 21 for tile coordinate (1188611, 831714)
# Cannot find tile image at level 20 for tile coordinate (594305, 415857)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.85401 24.03878 34.85406 24.03872 Successfully retrieved the image with maximum resolution!
# 34.87217 24.06185 34.87222 24.0618
# Cannot find tile image at level 23 for tile coordinate (4754984, 3326341)
# Cannot find tile image at level 22 for tile coordinate (2377492, 1663170)
# Cannot find tile image at level 21 for tile coordinate (1188746, 831585)
# Cannot find tile image at level 20 for tile coordinate (594373, 415792)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.87217 24.06185 34.87222 24.0618 Successfully retrieved the image with maximum resolution!
# 34.87522 25.63433 34.87527 25.63428
# Cannot find tile image at level 23 for tile coordinate (4791626, 3326254)
# Cannot find tile image at level 22 for tile coordinate (2395813, 1663127)
# Cannot find tile image at level 21 for tile coordinate (1197906, 831563)
# Cannot find tile image at level 20 for tile coordinate (598953, 415781)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.87522 25.63433 34.87527 25.63428 Successfully retrieved the image with maximum resolution!
# 34.88741 24.05097 34.88746 24.05092
# Cannot find tile image at level 23 for tile coordinate (4754731, 3325908)
# Cannot find tile image at level 22 for tile coordinate (2377365, 1662954)
# Cannot find tile image at level 21 for tile coordinate (1188682, 831477)
# Cannot find tile image at level 20 for tile coordinate (594341, 415738)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.88741 24.05097 34.88746 24.05092 Successfully retrieved the image with maximum resolution!
# 34.87509 25.73519 34.87514 25.73513
# Cannot find tile image at level 23 for tile coordinate (4793975, 3326258)
# Cannot find tile image at level 22 for tile coordinate (2396987, 1663129)
# Cannot find tile image at level 21 for tile coordinate (1198494, 831564)
# Cannot find tile image at level 20 for tile coordinate (599247, 415782)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.87509 25.73519 34.87514 25.73513 Successfully retrieved the image with maximum resolution!
# 34.8815 25.72556 34.88154 25.72551
# Cannot find tile image at level 23 for tile coordinate (4793751, 3326076)
# Cannot find tile image at level 22 for tile coordinate (2396875, 1663038)
# Cannot find tile image at level 21 for tile coordinate (1198437, 831519)
# Cannot find tile image at level 20 for tile coordinate (599218, 415759)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.8815 25.72556 34.88154 25.72551 Successfully retrieved the image with maximum resolution!
# 34.92356 24.76573 34.9236 24.76567
# Cannot find tile image at level 23 for tile coordinate (4771385, 3324881)
# Cannot find tile image at level 22 for tile coordinate (2385692, 1662440)
# Cannot find tile image at level 21 for tile coordinate (1192846, 831220)
# Cannot find tile image at level 20 for tile coordinate (596423, 415610)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92356 24.76573 34.9236 24.76567 Successfully retrieved the image with maximum resolution!
# 34.92538 24.77196 34.92542 24.77191
# Cannot find tile image at level 23 for tile coordinate (4771531, 3324829)
# Cannot find tile image at level 22 for tile coordinate (2385765, 1662414)
# Cannot find tile image at level 21 for tile coordinate (1192882, 831207)
# Cannot find tile image at level 20 for tile coordinate (596441, 415603)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92538 24.77196 34.92542 24.77191 Successfully retrieved the image with maximum resolution!
# 34.92728 24.90146 34.92733 24.90141
# Cannot find tile image at level 23 for tile coordinate (4774548, 3324775)
# Cannot find tile image at level 22 for tile coordinate (2387274, 1662387)
# Cannot find tile image at level 21 for tile coordinate (1193637, 831193)
# Cannot find tile image at level 20 for tile coordinate (596818, 415596)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92728 24.90146 34.92733 24.90141 Successfully retrieved the image with maximum resolution!
# 34.92888 24.95397 34.92892 24.95392
# Cannot find tile image at level 23 for tile coordinate (4775772, 3324730)
# Cannot find tile image at level 22 for tile coordinate (2387886, 1662365)
# Cannot find tile image at level 21 for tile coordinate (1193943, 831182)
# Cannot find tile image at level 20 for tile coordinate (596971, 415591)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92888 24.95397 34.92892 24.95392 Successfully retrieved the image with maximum resolution!
# 34.92925 24.9297 34.9293 24.92964
# Cannot find tile image at level 23 for tile coordinate (4775206, 3324719)
# Cannot find tile image at level 22 for tile coordinate (2387603, 1662359)
# Cannot find tile image at level 21 for tile coordinate (1193801, 831179)
# Cannot find tile image at level 20 for tile coordinate (596900, 415589)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92925 24.9297 34.9293 24.92964 Successfully retrieved the image with maximum resolution!
# 34.92908 25.01373 34.92912 25.01368
# Cannot find tile image at level 23 for tile coordinate (4777164, 3324724)
# Cannot find tile image at level 22 for tile coordinate (2388582, 1662362)
# Cannot find tile image at level 21 for tile coordinate (1194291, 831181)
# Cannot find tile image at level 20 for tile coordinate (597145, 415590)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92908 25.01373 34.92912 25.01368 Successfully retrieved the image with maximum resolution!
# 34.93105 24.90012 34.9311 24.90007
# Cannot find tile image at level 23 for tile coordinate (4774517, 3324668)
# Cannot find tile image at level 22 for tile coordinate (2387258, 1662334)
# Cannot find tile image at level 21 for tile coordinate (1193629, 831167)
# Cannot find tile image at level 20 for tile coordinate (596814, 415583)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93105 24.90012 34.9311 24.90007 Successfully retrieved the image with maximum resolution!
# 34.93134 24.99897 34.93138 24.99891
# Cannot find tile image at level 23 for tile coordinate (4776820, 3324660)
# Cannot find tile image at level 22 for tile coordinate (2388410, 1662330)
# Cannot find tile image at level 21 for tile coordinate (1194205, 831165)
# Cannot find tile image at level 20 for tile coordinate (597102, 415582)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93134 24.99897 34.93138 24.99891 Successfully retrieved the image with maximum resolution!
# 34.93142 25.00585 34.93147 25.0058
# Cannot find tile image at level 23 for tile coordinate (4776981, 3324658)
# Cannot find tile image at level 22 for tile coordinate (2388490, 1662329)
# Cannot find tile image at level 21 for tile coordinate (1194245, 831164)
# Cannot find tile image at level 20 for tile coordinate (597122, 415582)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93142 25.00585 34.93147 25.0058 Successfully retrieved the image with maximum resolution!
# 34.93155 24.99715 34.93159 24.9971
# Cannot find tile image at level 23 for tile coordinate (4776778, 3324654)
# Cannot find tile image at level 22 for tile coordinate (2388389, 1662327)
# Cannot find tile image at level 21 for tile coordinate (1194194, 831163)
# Cannot find tile image at level 20 for tile coordinate (597097, 415581)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93155 24.99715 34.93159 24.9971 Successfully retrieved the image with maximum resolution!
# 34.93303 24.81043 34.93308 24.81037
# Cannot find tile image at level 23 for tile coordinate (4772427, 3324612)
# Cannot find tile image at level 22 for tile coordinate (2386213, 1662306)
# Cannot find tile image at level 21 for tile coordinate (1193106, 831153)
# Cannot find tile image at level 20 for tile coordinate (596553, 415576)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93303 24.81043 34.93308 24.81037 Successfully retrieved the image with maximum resolution!
# 34.93214 24.95278 34.93219 24.95273
# Cannot find tile image at level 23 for tile coordinate (4775744, 3324637)
# Cannot find tile image at level 22 for tile coordinate (2387872, 1662318)
# Cannot find tile image at level 21 for tile coordinate (1193936, 831159)
# Cannot find tile image at level 20 for tile coordinate (596968, 415579)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93214 24.95278 34.93219 24.95273 Successfully retrieved the image with maximum resolution!
# 34.93282 24.88457 34.93287 24.88452
# Cannot find tile image at level 23 for tile coordinate (4774155, 3324618)
# Cannot find tile image at level 22 for tile coordinate (2387077, 1662309)
# Cannot find tile image at level 21 for tile coordinate (1193538, 831154)
# Cannot find tile image at level 20 for tile coordinate (596769, 415577)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93282 24.88457 34.93287 24.88452 Successfully retrieved the image with maximum resolution!
# 34.9323 24.98037 34.93235 24.98032
# Cannot find tile image at level 23 for tile coordinate (4776387, 3324633)
# Cannot find tile image at level 22 for tile coordinate (2388193, 1662316)
# Cannot find tile image at level 21 for tile coordinate (1194096, 831158)
# Cannot find tile image at level 20 for tile coordinate (597048, 415579)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.9323 24.98037 34.93235 24.98032 Successfully retrieved the image with maximum resolution!
# 34.93651 24.81539 34.93656 24.81534
# Cannot find tile image at level 23 for tile coordinate (4772543, 3324513)
# Cannot find tile image at level 22 for tile coordinate (2386271, 1662256)
# Cannot find tile image at level 21 for tile coordinate (1193135, 831128)
# Cannot find tile image at level 20 for tile coordinate (596567, 415564)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93651 24.81539 34.93656 24.81534 Successfully retrieved the image with maximum resolution!
# 34.93625 25.09232 34.93629 25.09226
# Cannot find tile image at level 23 for tile coordinate (4778996, 3324521)
# Cannot find tile image at level 22 for tile coordinate (2389498, 1662260)
# Cannot find tile image at level 21 for tile coordinate (1194749, 831130)
# Cannot find tile image at level 20 for tile coordinate (597374, 415565)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93625 25.09232 34.93629 25.09226 Successfully retrieved the image with maximum resolution!
# 34.92935 26.1468 34.9294 26.14674
# Cannot find tile image at level 23 for tile coordinate (4803567, 3324716)
# Cannot find tile image at level 22 for tile coordinate (2401783, 1662358)
# Cannot find tile image at level 21 for tile coordinate (1200891, 831179)
# Cannot find tile image at level 20 for tile coordinate (600445, 415589)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.92935 26.1468 34.9294 26.14674 Successfully retrieved the image with maximum resolution!
# 34.93271 26.13099 34.93276 26.13094
# Cannot find tile image at level 23 for tile coordinate (4803199, 3324621)
# Cannot find tile image at level 22 for tile coordinate (2401599, 1662310)
# Cannot find tile image at level 21 for tile coordinate (1200799, 831155)
# Cannot find tile image at level 20 for tile coordinate (600399, 415577)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93271 26.13099 34.93276 26.13094 Successfully retrieved the image with maximum resolution!
# 34.95049 25.2037 34.95053 25.20364
# Cannot find tile image at level 23 for tile coordinate (4781591, 3324116)
# Cannot find tile image at level 22 for tile coordinate (2390795, 1662058)
# Cannot find tile image at level 21 for tile coordinate (1195397, 831029)
# Cannot find tile image at level 20 for tile coordinate (597698, 415514)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95049 25.2037 34.95053 25.20364 Successfully retrieved the image with maximum resolution!
# 34.95065 25.20921 34.9507 25.20915
# Cannot find tile image at level 23 for tile coordinate (4781719, 3324111)
# Cannot find tile image at level 22 for tile coordinate (2390859, 1662055)
# Cannot find tile image at level 21 for tile coordinate (1195429, 831027)
# Cannot find tile image at level 20 for tile coordinate (597714, 415513)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95065 25.20921 34.9507 25.20915 Successfully retrieved the image with maximum resolution!
# 34.93885 26.12521 34.9389 26.12516
# Cannot find tile image at level 23 for tile coordinate (4803064, 3324446)
# Cannot find tile image at level 22 for tile coordinate (2401532, 1662223)
# Cannot find tile image at level 21 for tile coordinate (1200766, 831111)
# Cannot find tile image at level 20 for tile coordinate (600383, 415555)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.93885 26.12521 34.9389 26.12516 Successfully retrieved the image with maximum resolution!
# 34.95101 25.3341 34.95106 25.33405
# Cannot find tile image at level 23 for tile coordinate (4784630, 3324101)
# Cannot find tile image at level 22 for tile coordinate (2392315, 1662050)
# Cannot find tile image at level 21 for tile coordinate (1196157, 831025)
# Cannot find tile image at level 20 for tile coordinate (598078, 415512)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95101 25.3341 34.95106 25.33405 Successfully retrieved the image with maximum resolution!
# 34.95622 24.74982 34.95626 24.74976
# Cannot find tile image at level 23 for tile coordinate (4771015, 3323953)
# Cannot find tile image at level 22 for tile coordinate (2385507, 1661976)
# Cannot find tile image at level 21 for tile coordinate (1192753, 830988)
# Cannot find tile image at level 20 for tile coordinate (596376, 415494)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95622 24.74982 34.95626 24.74976 Successfully retrieved the image with maximum resolution!
# 34.94056 26.12505 34.94061 26.12499
# Cannot find tile image at level 23 for tile coordinate (4803060, 3324398)
# Cannot find tile image at level 22 for tile coordinate (2401530, 1662199)
# Cannot find tile image at level 21 for tile coordinate (1200765, 831099)
# Cannot find tile image at level 20 for tile coordinate (600382, 415549)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.94056 26.12505 34.94061 26.12499 Successfully retrieved the image with maximum resolution!
# 34.95373 25.16919 34.95377 25.16913
# Cannot find tile image at level 23 for tile coordinate (4780787, 3324024)
# Cannot find tile image at level 22 for tile coordinate (2390393, 1662012)
# Cannot find tile image at level 21 for tile coordinate (1195196, 831006)
# Cannot find tile image at level 20 for tile coordinate (597598, 415503)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95373 25.16919 34.95377 25.16913 Successfully retrieved the image with maximum resolution!
# 34.94442 26.12638 34.94447 26.12633
# Cannot find tile image at level 23 for tile coordinate (4803091, 3324288)
# Cannot find tile image at level 22 for tile coordinate (2401545, 1662144)
# Cannot find tile image at level 21 for tile coordinate (1200772, 831072)
# Cannot find tile image at level 20 for tile coordinate (600386, 415536)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.94442 26.12638 34.94447 26.12633 Successfully retrieved the image with maximum resolution!
# 34.95735 25.24145 34.95739 25.24139
# Cannot find tile image at level 23 for tile coordinate (4782471, 3323921)
# Cannot find tile image at level 22 for tile coordinate (2391235, 1661960)
# Cannot find tile image at level 21 for tile coordinate (1195617, 830980)
# Cannot find tile image at level 20 for tile coordinate (597808, 415490)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95735 25.24145 34.95739 25.24139 Successfully retrieved the image with maximum resolution!
# 34.95741 25.24484 34.95746 25.24478
# Cannot find tile image at level 23 for tile coordinate (4782550, 3323919)
# Cannot find tile image at level 22 for tile coordinate (2391275, 1661959)
# Cannot find tile image at level 21 for tile coordinate (1195637, 830979)
# Cannot find tile image at level 20 for tile coordinate (597818, 415489)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.95741 25.24484 34.95746 25.24478 Successfully retrieved the image with maximum resolution!
# 34.97416 24.74865 34.97421 24.7486
# Cannot find tile image at level 23 for tile coordinate (4770988, 3323442)
# Cannot find tile image at level 22 for tile coordinate (2385494, 1661721)
# Cannot find tile image at level 21 for tile coordinate (1192747, 830860)
# Cannot find tile image at level 20 for tile coordinate (596373, 415430)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.97416 24.74865 34.97421 24.7486 Successfully retrieved the image with maximum resolution!
# 34.96447 26.13319 34.96452 26.13313
# Cannot find tile image at level 23 for tile coordinate (4803250, 3323718)
# Cannot find tile image at level 22 for tile coordinate (2401625, 1661859)
# Cannot find tile image at level 21 for tile coordinate (1200812, 830929)
# Cannot find tile image at level 20 for tile coordinate (600406, 415464)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.96447 26.13319 34.96452 26.13313 Successfully retrieved the image with maximum resolution!
# 34.98045 25.31026 34.9805 25.3102
# Cannot find tile image at level 23 for tile coordinate (4784074, 3323264)
# Cannot find tile image at level 22 for tile coordinate (2392037, 1661632)
# Cannot find tile image at level 21 for tile coordinate (1196018, 830816)
# Cannot find tile image at level 20 for tile coordinate (598009, 415408)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.98045 25.31026 34.9805 25.3102 Successfully retrieved the image with maximum resolution!
# 34.97706 25.99922 34.97711 25.99916
# Cannot find tile image at level 23 for tile coordinate (4800128, 3323360)
# Cannot find tile image at level 22 for tile coordinate (2400064, 1661680)
# Cannot find tile image at level 21 for tile coordinate (1200032, 830840)
# Cannot find tile image at level 20 for tile coordinate (600016, 415420)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.97706 25.99922 34.97711 25.99916 Successfully retrieved the image with maximum resolution!
# 34.99054 25.4544 34.99059 25.45435
# Cannot find tile image at level 23 for tile coordinate (4787433, 3322977)
# Cannot find tile image at level 22 for tile coordinate (2393716, 1661488)
# Cannot find tile image at level 21 for tile coordinate (1196858, 830744)
# Cannot find tile image at level 20 for tile coordinate (598429, 415372)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.99054 25.4544 34.99059 25.45435 Successfully retrieved the image with maximum resolution!
# 34.99911 24.69423 34.99916 24.69418
# Cannot find tile image at level 23 for tile coordinate (4769720, 3322733)
# Cannot find tile image at level 22 for tile coordinate (2384860, 1661366)
# Cannot find tile image at level 21 for tile coordinate (1192430, 830683)
# Cannot find tile image at level 20 for tile coordinate (596215, 415341)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.99911 24.69423 34.99916 24.69418 Successfully retrieved the image with maximum resolution!
# 35.0089 24.59702 35.00894 24.59697
# Cannot find tile image at level 23 for tile coordinate (4767454, 3322455)
# Cannot find tile image at level 22 for tile coordinate (2383727, 1661227)
# Cannot find tile image at level 21 for tile coordinate (1191863, 830613)
# Cannot find tile image at level 20 for tile coordinate (595931, 415306)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.0089 24.59702 35.00894 24.59697 Successfully retrieved the image with maximum resolution!
# 34.99254 26.11051 34.99259 26.11046
# Cannot find tile image at level 23 for tile coordinate (4802721, 3322920)
# Cannot find tile image at level 22 for tile coordinate (2401360, 1661460)
# Cannot find tile image at level 21 for tile coordinate (1200680, 830730)
# Cannot find tile image at level 20 for tile coordinate (600340, 415365)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 34.99254 26.11051 34.99259 26.11046 Successfully retrieved the image with maximum resolution!
# 35.00291 25.73668 35.00296 25.73662
# Cannot find tile image at level 23 for tile coordinate (4794010, 3322625)
# Cannot find tile image at level 22 for tile coordinate (2397005, 1661312)
# Cannot find tile image at level 21 for tile coordinate (1198502, 830656)
# Cannot find tile image at level 20 for tile coordinate (599251, 415328)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.00291 25.73668 35.00296 25.73662 Successfully retrieved the image with maximum resolution!
# 35.00322 25.73637 35.00327 25.73632
# Cannot find tile image at level 23 for tile coordinate (4794003, 3322616)
# Cannot find tile image at level 22 for tile coordinate (2397001, 1661308)
# Cannot find tile image at level 21 for tile coordinate (1198500, 830654)
# Cannot find tile image at level 20 for tile coordinate (599250, 415327)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.00322 25.73637 35.00327 25.73632 Successfully retrieved the image with maximum resolution!
# 35.00498 26.14635 35.00502 26.1463
# Cannot find tile image at level 23 for tile coordinate (4803556, 3322566)
# Cannot find tile image at level 22 for tile coordinate (2401778, 1661283)
# Cannot find tile image at level 21 for tile coordinate (1200889, 830641)
# Cannot find tile image at level 20 for tile coordinate (600444, 415320)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.00498 26.14635 35.00502 26.1463 Successfully retrieved the image with maximum resolution!
# 35.01713 25.86102 35.01718 25.86096
# Cannot find tile image at level 23 for tile coordinate (4796908, 3322220)
# Cannot find tile image at level 22 for tile coordinate (2398454, 1661110)
# Cannot find tile image at level 21 for tile coordinate (1199227, 830555)
# Cannot find tile image at level 20 for tile coordinate (599613, 415277)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.01713 25.86102 35.01718 25.86096 Successfully retrieved the image with maximum resolution!
# 35.01738 25.86023 35.01742 25.86018
# Cannot find tile image at level 23 for tile coordinate (4796889, 3322213)
# Cannot find tile image at level 22 for tile coordinate (2398444, 1661106)
# Cannot find tile image at level 21 for tile coordinate (1199222, 830553)
# Cannot find tile image at level 20 for tile coordinate (599611, 415276)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.01738 25.86023 35.01742 25.86018 Successfully retrieved the image with maximum resolution!
# 35.02005 26.0015 35.0201 26.00145
# Cannot find tile image at level 23 for tile coordinate (4800181, 3322137)
# Cannot find tile image at level 22 for tile coordinate (2400090, 1661068)
# Cannot find tile image at level 21 for tile coordinate (1200045, 830534)
# Cannot find tile image at level 20 for tile coordinate (600022, 415267)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.02005 26.0015 35.0201 26.00145 Successfully retrieved the image with maximum resolution!
# 35.03079 25.91851 35.03084 25.91846
# Cannot find tile image at level 23 for tile coordinate (4798247, 3321831)
# Cannot find tile image at level 22 for tile coordinate (2399123, 1660915)
# Cannot find tile image at level 21 for tile coordinate (1199561, 830458)
# Cannot find tile image at level 20 for tile coordinate (599780, 415229)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.03079 25.91851 35.03084 25.91846 Successfully retrieved the image with maximum resolution!
# 35.05543 24.75166 35.05547 24.7516
# Cannot find tile image at level 23 for tile coordinate (4771058, 3321130)
# Cannot find tile image at level 22 for tile coordinate (2385529, 1660565)
# Cannot find tile image at level 21 for tile coordinate (1192764, 830282)
# Cannot find tile image at level 20 for tile coordinate (596382, 415141)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.05543 24.75166 35.05547 24.7516 Successfully retrieved the image with maximum resolution!
# 35.08092 24.73867 35.08096 24.73861
# Cannot find tile image at level 23 for tile coordinate (4770755, 3320405)
# Cannot find tile image at level 22 for tile coordinate (2385377, 1660202)
# Cannot find tile image at level 21 for tile coordinate (1192688, 830101)
# Cannot find tile image at level 20 for tile coordinate (596344, 415050)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.08092 24.73867 35.08096 24.73861 Successfully retrieved the image with maximum resolution!
# 35.08116 24.73662 35.08121 24.73657
# Cannot find tile image at level 23 for tile coordinate (4770707, 3320398)
# Cannot find tile image at level 22 for tile coordinate (2385353, 1660199)
# Cannot find tile image at level 21 for tile coordinate (1192676, 830099)
# Cannot find tile image at level 20 for tile coordinate (596338, 415049)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.08116 24.73662 35.08121 24.73657 Successfully retrieved the image with maximum resolution!
# 35.0637 26.24772 35.06375 26.24767
# Cannot find tile image at level 23 for tile coordinate (4805919, 3320895)
# Cannot find tile image at level 22 for tile coordinate (2402959, 1660447)
# Cannot find tile image at level 21 for tile coordinate (1201479, 830223)
# Cannot find tile image at level 20 for tile coordinate (600739, 415111)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.0637 26.24772 35.06375 26.24767 Successfully retrieved the image with maximum resolution!
# 35.09454 24.6898 35.09459 24.68975
# Cannot find tile image at level 23 for tile coordinate (4769616, 3320017)
# Cannot find tile image at level 22 for tile coordinate (2384808, 1660008)
# Cannot find tile image at level 21 for tile coordinate (1192404, 830004)
# Cannot find tile image at level 20 for tile coordinate (596202, 415002)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.09454 24.6898 35.09459 24.68975 Successfully retrieved the image with maximum resolution!
# 35.09668 24.61698 35.09673 24.61692
# Cannot find tile image at level 23 for tile coordinate (4767919, 3319956)
# Cannot find tile image at level 22 for tile coordinate (2383959, 1659978)
# Cannot find tile image at level 21 for tile coordinate (1191979, 829989)
# Cannot find tile image at level 20 for tile coordinate (595989, 414994)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.09668 24.61698 35.09673 24.61692 Successfully retrieved the image with maximum resolution!
# 35.16668 24.41861 35.16673 24.41855
# Cannot find tile image at level 23 for tile coordinate (4763297, 3317961)
# Cannot find tile image at level 22 for tile coordinate (2381648, 1658980)
# Cannot find tile image at level 21 for tile coordinate (1190824, 829490)
# Cannot find tile image at level 20 for tile coordinate (595412, 414745)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.16668 24.41861 35.16673 24.41855 Successfully retrieved the image with maximum resolution!
# 35.157 25.84761 35.15704 25.84755
# Cannot find tile image at level 23 for tile coordinate (4796595, 3318237)
# Cannot find tile image at level 22 for tile coordinate (2398297, 1659118)
# Cannot find tile image at level 21 for tile coordinate (1199148, 829559)
# Cannot find tile image at level 20 for tile coordinate (599574, 414779)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.157 25.84761 35.15704 25.84755 Successfully retrieved the image with maximum resolution!
# 35.17574 24.39289 35.17579 24.39283
# Cannot find tile image at level 23 for tile coordinate (4762698, 3317703)
# Cannot find tile image at level 22 for tile coordinate (2381349, 1658851)
# Cannot find tile image at level 21 for tile coordinate (1190674, 829425)
# Cannot find tile image at level 20 for tile coordinate (595337, 414712)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17574 24.39289 35.17579 24.39283 Successfully retrieved the image with maximum resolution!
# 35.16253 25.88068 35.16258 25.88063
# Cannot find tile image at level 23 for tile coordinate (4797366, 3318080)
# Cannot find tile image at level 22 for tile coordinate (2398683, 1659040)
# Cannot find tile image at level 21 for tile coordinate (1199341, 829520)
# Cannot find tile image at level 20 for tile coordinate (599670, 414760)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.16253 25.88068 35.16258 25.88063 Successfully retrieved the image with maximum resolution!
# 35.17778 24.2659 35.17782 24.26585
# Cannot find tile image at level 23 for tile coordinate (4759739, 3317645)
# Cannot find tile image at level 22 for tile coordinate (2379869, 1658822)
# Cannot find tile image at level 21 for tile coordinate (1189934, 829411)
# Cannot find tile image at level 20 for tile coordinate (594967, 414705)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17778 24.2659 35.17782 24.26585 Successfully retrieved the image with maximum resolution!
# 35.17793 24.23552 35.17798 24.23546
# Cannot find tile image at level 23 for tile coordinate (4759031, 3317641)
# Cannot find tile image at level 22 for tile coordinate (2379515, 1658820)
# Cannot find tile image at level 21 for tile coordinate (1189757, 829410)
# Cannot find tile image at level 20 for tile coordinate (594878, 414705)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17793 24.23552 35.17798 24.23546 Successfully retrieved the image with maximum resolution!
# 35.17886 24.12167 35.1789 24.12162
# Cannot find tile image at level 23 for tile coordinate (4756378, 3317614)
# Cannot find tile image at level 22 for tile coordinate (2378189, 1658807)
# Cannot find tile image at level 21 for tile coordinate (1189094, 829403)
# Cannot find tile image at level 20 for tile coordinate (594547, 414701)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17886 24.12167 35.1789 24.12162 Successfully retrieved the image with maximum resolution!
# 35.17914 24.27082 35.17918 24.27077
# Cannot find tile image at level 23 for tile coordinate (4759853, 3317606)
# Cannot find tile image at level 22 for tile coordinate (2379926, 1658803)
# Cannot find tile image at level 21 for tile coordinate (1189963, 829401)
# Cannot find tile image at level 20 for tile coordinate (594981, 414700)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17914 24.27082 35.17918 24.27077 Successfully retrieved the image with maximum resolution!
# 35.16607 25.88281 35.16611 25.88276
# Cannot find tile image at level 23 for tile coordinate (4797416, 3317979)
# Cannot find tile image at level 22 for tile coordinate (2398708, 1658989)
# Cannot find tile image at level 21 for tile coordinate (1199354, 829494)
# Cannot find tile image at level 20 for tile coordinate (599677, 414747)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.16607 25.88281 35.16611 25.88276 Successfully retrieved the image with maximum resolution!
# 35.18579 24.36191 35.18583 24.36186
# Cannot find tile image at level 23 for tile coordinate (4761976, 3317417)
# Cannot find tile image at level 22 for tile coordinate (2380988, 1658708)
# Cannot find tile image at level 21 for tile coordinate (1190494, 829354)
# Cannot find tile image at level 20 for tile coordinate (595247, 414677)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.18579 24.36191 35.18583 24.36186 Successfully retrieved the image with maximum resolution!
# 35.18622 24.36148 35.18627 24.36143
# Cannot find tile image at level 23 for tile coordinate (4761966, 3317404)
# Cannot find tile image at level 22 for tile coordinate (2380983, 1658702)
# Cannot find tile image at level 21 for tile coordinate (1190491, 829351)
# Cannot find tile image at level 20 for tile coordinate (595245, 414675)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.18622 24.36148 35.18627 24.36143 Successfully retrieved the image with maximum resolution!
# 35.18706 24.22102 35.18711 24.22096
# Cannot find tile image at level 23 for tile coordinate (4758693, 3317380)
# Cannot find tile image at level 22 for tile coordinate (2379346, 1658690)
# Cannot find tile image at level 21 for tile coordinate (1189673, 829345)
# Cannot find tile image at level 20 for tile coordinate (594836, 414672)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.18706 24.22102 35.18711 24.22096 Successfully retrieved the image with maximum resolution!
# 35.17265 25.89391 35.1727 25.89386
# Cannot find tile image at level 23 for tile coordinate (4797674, 3317791)
# Cannot find tile image at level 22 for tile coordinate (2398837, 1658895)
# Cannot find tile image at level 21 for tile coordinate (1199418, 829447)
# Cannot find tile image at level 20 for tile coordinate (599709, 414723)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17265 25.89391 35.1727 25.89386 Successfully retrieved the image with maximum resolution!
# 35.1776 25.71286 35.17765 25.71281
# Cannot find tile image at level 23 for tile coordinate (4793455, 3317650)
# Cannot find tile image at level 22 for tile coordinate (2396727, 1658825)
# Cannot find tile image at level 21 for tile coordinate (1198363, 829412)
# Cannot find tile image at level 20 for tile coordinate (599181, 414706)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.1776 25.71286 35.17765 25.71281 Successfully retrieved the image with maximum resolution!
# 35.19152 24.14539 35.19157 24.14534
# Cannot find tile image at level 23 for tile coordinate (4756931, 3317253)
# Cannot find tile image at level 22 for tile coordinate (2378465, 1658626)
# Cannot find tile image at level 21 for tile coordinate (1189232, 829313)
# Cannot find tile image at level 20 for tile coordinate (594616, 414656)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.19152 24.14539 35.19157 24.14534 Successfully retrieved the image with maximum resolution!
# 35.16984 26.31623 35.16989 26.31617
# Cannot find tile image at level 23 for tile coordinate (4807515, 3317871)
# Cannot find tile image at level 22 for tile coordinate (2403757, 1658935)
# Cannot find tile image at level 21 for tile coordinate (1201878, 829467)
# Cannot find tile image at level 20 for tile coordinate (600939, 414733)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.16984 26.31623 35.16989 26.31617 Successfully retrieved the image with maximum resolution!
# 35.17758 25.89321 35.17763 25.89316
# Cannot find tile image at level 23 for tile coordinate (4797658, 3317651)
# Cannot find tile image at level 22 for tile coordinate (2398829, 1658825)
# Cannot find tile image at level 21 for tile coordinate (1199414, 829412)
# Cannot find tile image at level 20 for tile coordinate (599707, 414706)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.17758 25.89321 35.17763 25.89316 Successfully retrieved the image with maximum resolution!
# 35.19238 24.14394 35.19242 24.14389
# Cannot find tile image at level 23 for tile coordinate (4756897, 3317229)
# Cannot find tile image at level 22 for tile coordinate (2378448, 1658614)
# Cannot find tile image at level 21 for tile coordinate (1189224, 829307)
# Cannot find tile image at level 20 for tile coordinate (594612, 414653)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.19238 24.14394 35.19242 24.14389 Successfully retrieved the image with maximum resolution!
# 35.1928 24.38056 35.19284 24.38051
# Cannot find tile image at level 23 for tile coordinate (4762411, 3317217)
# Cannot find tile image at level 22 for tile coordinate (2381205, 1658608)
# Cannot find tile image at level 21 for tile coordinate (1190602, 829304)
# Cannot find tile image at level 20 for tile coordinate (595301, 414652)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.1928 24.38056 35.19284 24.38051 Successfully retrieved the image with maximum resolution!
# 35.19929 24.06496 35.19933 24.06491
# Cannot find tile image at level 23 for tile coordinate (4755057, 3317032)
# Cannot find tile image at level 22 for tile coordinate (2377528, 1658516)
# Cannot find tile image at level 21 for tile coordinate (1188764, 829258)
# Cannot find tile image at level 20 for tile coordinate (594382, 414629)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.19929 24.06496 35.19933 24.06491 Successfully retrieved the image with maximum resolution!
# 35.20016 24.13298 35.20021 24.13293
# Cannot find tile image at level 23 for tile coordinate (4756642, 3317007)
# Cannot find tile image at level 22 for tile coordinate (2378321, 1658503)
# Cannot find tile image at level 21 for tile coordinate (1189160, 829251)
# Cannot find tile image at level 20 for tile coordinate (594580, 414625)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.20016 24.13298 35.20021 24.13293 Successfully retrieved the image with maximum resolution!
# 35.18717 25.85267 35.18722 25.85261
# Cannot find tile image at level 23 for tile coordinate (4796713, 3317377)
# Cannot find tile image at level 22 for tile coordinate (2398356, 1658688)
# Cannot find tile image at level 21 for tile coordinate (1199178, 829344)
# Cannot find tile image at level 20 for tile coordinate (599589, 414672)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.18717 25.85267 35.18722 25.85261 Successfully retrieved the image with maximum resolution!
# 35.18677 25.95273 35.18681 25.95267
# Cannot find tile image at level 23 for tile coordinate (4799045, 3317389)
# Cannot find tile image at level 22 for tile coordinate (2399522, 1658694)
# Cannot find tile image at level 21 for tile coordinate (1199761, 829347)
# Cannot find tile image at level 20 for tile coordinate (599880, 414673)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.18677 25.95273 35.18681 25.95267 Successfully retrieved the image with maximum resolution!
# 35.19306 25.72056 35.19311 25.72051
# Cannot find tile image at level 23 for tile coordinate (4793635, 3317209)
# Cannot find tile image at level 22 for tile coordinate (2396817, 1658604)
# Cannot find tile image at level 21 for tile coordinate (1198408, 829302)
# Cannot find tile image at level 20 for tile coordinate (599204, 414651)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.19306 25.72056 35.19311 25.72051 Successfully retrieved the image with maximum resolution!
# 35.19318 25.85906 35.19322 25.85901
# Cannot find tile image at level 23 for tile coordinate (4796862, 3317206)
# Cannot find tile image at level 22 for tile coordinate (2398431, 1658603)
# Cannot find tile image at level 21 for tile coordinate (1199215, 829301)
# Cannot find tile image at level 20 for tile coordinate (599607, 414650)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.19318 25.85906 35.19322 25.85901 Successfully retrieved the image with maximum resolution!
# 35.19463 25.86326 35.19467 25.86321
# Cannot find tile image at level 23 for tile coordinate (4796960, 3317165)
# Cannot find tile image at level 22 for tile coordinate (2398480, 1658582)
# Cannot find tile image at level 21 for tile coordinate (1199240, 829291)
# Cannot find tile image at level 20 for tile coordinate (599620, 414645)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.19463 25.86326 35.19467 25.86321 Successfully retrieved the image with maximum resolution!
# 35.20138 25.71716 35.20142 25.7171
# Cannot find tile image at level 23 for tile coordinate (4793555, 3316972)
# Cannot find tile image at level 22 for tile coordinate (2396777, 1658486)
# Cannot find tile image at level 21 for tile coordinate (1198388, 829243)
# Cannot find tile image at level 20 for tile coordinate (599194, 414621)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.20138 25.71716 35.20142 25.7171 Successfully retrieved the image with maximum resolution!
# 35.20451 25.72224 35.20456 25.72219
# Cannot find tile image at level 23 for tile coordinate (4793674, 3316883)
# Cannot find tile image at level 22 for tile coordinate (2396837, 1658441)
# Cannot find tile image at level 21 for tile coordinate (1198418, 829220)
# Cannot find tile image at level 20 for tile coordinate (599209, 414610)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.20451 25.72224 35.20456 25.72219 Successfully retrieved the image with maximum resolution!
# 35.22274 23.67364 35.22279 23.67359
# Cannot find tile image at level 23 for tile coordinate (4745938, 3316363)
# Cannot find tile image at level 22 for tile coordinate (2372969, 1658181)
# Cannot find tile image at level 21 for tile coordinate (1186484, 829090)
# Cannot find tile image at level 20 for tile coordinate (593242, 414545)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.22274 23.67364 35.22279 23.67359 Successfully retrieved the image with maximum resolution!
# 35.22314 23.67528 35.22318 23.67523
# Cannot find tile image at level 23 for tile coordinate (4745976, 3316352)
# Cannot find tile image at level 22 for tile coordinate (2372988, 1658176)
# Cannot find tile image at level 21 for tile coordinate (1186494, 829088)
# Cannot find tile image at level 20 for tile coordinate (593247, 414544)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 35.22314 23.67528 35.22318 23.67523 Successfully retrieved the image with maximum resolution!
# 35.22379 23.67631 35.22384 23.67625
# ...
# Cannot find tile image at level 21 for tile coordinate (1172786, 811514)
# Cannot find tile image at level 20 for tile coordinate (586393, 405757)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.64967 21.32222 37.64972 21.32216 Successfully retrieved the image with maximum resolution!
# 37.67895 23.15338 37.679 23.15333
# Cannot find tile image at level 23 for tile coordinate (4733815, 3245197)
# Cannot find tile image at level 22 for tile coordinate (2366907, 1622598)
# Cannot find tile image at level 21 for tile coordinate (1183453, 811299)
# Cannot find tile image at level 20 for tile coordinate (591726, 405649)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.67895 23.15338 37.679 23.15333 Successfully retrieved the image with maximum resolution!
# 37.67878 24.98303 37.67882 24.98297
# Cannot find tile image at level 23 for tile coordinate (4776449, 3245203)
# Cannot find tile image at level 22 for tile coordinate (2388224, 1622601)
# Cannot find tile image at level 21 for tile coordinate (1194112, 811300)
# Cannot find tile image at level 20 for tile coordinate (597056, 405650)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.67878 24.98303 37.67882 24.98297 Successfully retrieved the image with maximum resolution!
# 37.67873 25.02103 37.67878 25.02097
# Cannot find tile image at level 23 for tile coordinate (4777334, 3245204)
# Cannot find tile image at level 22 for tile coordinate (2388667, 1622602)
# Cannot find tile image at level 21 for tile coordinate (1194333, 811301)
# Cannot find tile image at level 20 for tile coordinate (597166, 405650)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.67873 25.02103 37.67878 25.02097 Successfully retrieved the image with maximum resolution!
# 37.66434 26.26879 37.66439 26.26874
# Cannot find tile image at level 23 for tile coordinate (4806410, 3245628)
# Cannot find tile image at level 22 for tile coordinate (2403205, 1622814)
# Cannot find tile image at level 21 for tile coordinate (1201602, 811407)
# Cannot find tile image at level 20 for tile coordinate (600801, 405703)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.66434 26.26879 37.66439 26.26874 Successfully retrieved the image with maximum resolution!
# 37.66571 26.27103 37.66575 26.27098
# Cannot find tile image at level 23 for tile coordinate (4806462, 3245587)
# Cannot find tile image at level 22 for tile coordinate (2403231, 1622793)
# Cannot find tile image at level 21 for tile coordinate (1201615, 811397)
# Cannot find tile image at level 20 for tile coordinate (600807, 405698)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.66571 26.27103 37.66575 26.27098 Successfully retrieved the image with maximum resolution!
# 37.64717 20.84131 37.64721 20.84125
# Cannot find tile image at level 23 for tile coordinate (4679940, 3246133)
# Cannot find tile image at level 22 for tile coordinate (2339970, 1623066)
# Cannot find tile image at level 21 for tile coordinate (1169985, 811533)
# Cannot find tile image at level 20 for tile coordinate (584992, 405766)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.64717 20.84131 37.64721 20.84125 Successfully retrieved the image with maximum resolution!
# 37.66755 26.27573 37.66759 26.27567
# Cannot find tile image at level 23 for tile coordinate (4806571, 3245533)
# Cannot find tile image at level 22 for tile coordinate (2403285, 1622766)
# Cannot find tile image at level 21 for tile coordinate (1201642, 811383)
# Cannot find tile image at level 20 for tile coordinate (600821, 405691)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.66755 26.27573 37.66759 26.27567 Successfully retrieved the image with maximum resolution!
# 37.66962 26.27647 37.66966 26.27641
# Cannot find tile image at level 23 for tile coordinate (4806588, 3245472)
# Cannot find tile image at level 22 for tile coordinate (2403294, 1622736)
# Cannot find tile image at level 21 for tile coordinate (1201647, 811368)
# Cannot find tile image at level 20 for tile coordinate (600823, 405684)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.66962 26.27647 37.66966 26.27641 Successfully retrieved the image with maximum resolution!
# 37.6509 20.81345 37.65094 20.81339
# Cannot find tile image at level 23 for tile coordinate (4679291, 3246023)
# Cannot find tile image at level 22 for tile coordinate (2339645, 1623011)
# Cannot find tile image at level 21 for tile coordinate (1169822, 811505)
# Cannot find tile image at level 20 for tile coordinate (584911, 405752)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.6509 20.81345 37.65094 20.81339 Successfully retrieved the image with maximum resolution!
# 37.67197 26.28127 37.67201 26.28121
# Cannot find tile image at level 23 for tile coordinate (4806700, 3245403)
# Cannot find tile image at level 22 for tile coordinate (2403350, 1622701)
# Cannot find tile image at level 21 for tile coordinate (1201675, 811350)
# Cannot find tile image at level 20 for tile coordinate (600837, 405675)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.67197 26.28127 37.67201 26.28121 Successfully retrieved the image with maximum resolution!
# 37.66044 26.88439 37.66049 26.88433
# Cannot find tile image at level 23 for tile coordinate (4820754, 3245742)
# Cannot find tile image at level 22 for tile coordinate (2410377, 1622871)
# Cannot find tile image at level 21 for tile coordinate (1205188, 811435)
# Cannot find tile image at level 20 for tile coordinate (602594, 405717)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.66044 26.88439 37.66049 26.88433 Successfully retrieved the image with maximum resolution!
# 37.6958 24.06015 37.69585 24.06009
# Cannot find tile image at level 23 for tile coordinate (4754944, 3244701)
# Cannot find tile image at level 22 for tile coordinate (2377472, 1622350)
# Cannot find tile image at level 21 for tile coordinate (1188736, 811175)
# Cannot find tile image at level 20 for tile coordinate (594368, 405587)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.6958 24.06015 37.69585 24.06009 Successfully retrieved the image with maximum resolution!
# 37.6542 20.85449 37.65424 20.85443
# Cannot find tile image at level 23 for tile coordinate (4680247, 3245926)
# Cannot find tile image at level 22 for tile coordinate (2340123, 1622963)
# Cannot find tile image at level 21 for tile coordinate (1170061, 811481)
# Cannot find tile image at level 20 for tile coordinate (585030, 405740)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.6542 20.85449 37.65424 20.85443 Successfully retrieved the image with maximum resolution!
# 37.66629 21.30333 37.66633 21.30327
# Cannot find tile image at level 23 for tile coordinate (4690706, 3245570)
# Cannot find tile image at level 22 for tile coordinate (2345353, 1622785)
# Cannot find tile image at level 21 for tile coordinate (1172676, 811392)
# Cannot find tile image at level 20 for tile coordinate (586338, 405696)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.66629 21.30333 37.66633 21.30327 Successfully retrieved the image with maximum resolution!
# 37.69728 24.06222 37.69733 24.06216
# Cannot find tile image at level 23 for tile coordinate (4754992, 3244658)
# Cannot find tile image at level 22 for tile coordinate (2377496, 1622329)
# Cannot find tile image at level 21 for tile coordinate (1188748, 811164)
# Cannot find tile image at level 20 for tile coordinate (594374, 405582)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.69728 24.06222 37.69733 24.06216 Successfully retrieved the image with maximum resolution!
# 37.6949 24.93313 37.69494 24.93307
# Cannot find tile image at level 23 for tile coordinate (4775286, 3244728)
# Cannot find tile image at level 22 for tile coordinate (2387643, 1622364)
# Cannot find tile image at level 21 for tile coordinate (1193821, 811182)
# Cannot find tile image at level 20 for tile coordinate (596910, 405591)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.6949 24.93313 37.69494 24.93307 Successfully retrieved the image with maximum resolution!
# 37.69857 23.26604 37.69862 23.26598
# Cannot find tile image at level 23 for tile coordinate (4736440, 3244620)
# Cannot find tile image at level 22 for tile coordinate (2368220, 1622310)
# Cannot find tile image at level 21 for tile coordinate (1184110, 811155)
# Cannot find tile image at level 20 for tile coordinate (592055, 405577)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.69857 23.26604 37.69862 23.26598 Successfully retrieved the image with maximum resolution!
# 37.65898 20.8056 37.65902 20.80554
# Cannot find tile image at level 23 for tile coordinate (4679108, 3245786)
# Cannot find tile image at level 22 for tile coordinate (2339554, 1622893)
# Cannot find tile image at level 21 for tile coordinate (1169777, 811446)
# Cannot find tile image at level 20 for tile coordinate (584888, 405723)
# Finish the aerial image retrieval, store the image aerialImage_19.jpeg in folder /Users/Zack/0_thesis_bing/incoming
# 37.65898 20.8056 37.65902 20.80554 Successfully retrieved the image with maximum resolution!
# 37.67333 21.3032 37.67337 21.30314
# Cannot find tile image at level 23 for tile coordinate (4690703, 3245363)
# Cannot find tile image at level 22 for tile coordinate (2345351, 1622681)
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\envs\thesis\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\Anaconda3\envs\thesis\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ~\Anaconda3\envs\thesis\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# ~\Anaconda3\envs\thesis\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\Anaconda3\envs\thesis\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\Anaconda3\envs\thesis\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\Anaconda3\envs\thesis\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\thesis\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-4-d7cd75ac539e> in <module>
#      14
#      15     imgretrieval = AerialImageRetrieval(lat1, lon1, lat2, lon2)
# ---> 16     if imgretrieval.max_resolution_imagery_retrieval():
#      17         print(lat1, lon1, lat2, lon2, "Successfully retrieved the image with maximum resolution!")
#      18     else:
#
# ~\0_seawarden\python\detection\aerialImageRetrieval_2.py in max_resolution_imagery_retrieval(self)
#      77             retrieve_sucess = False
#      78             for tileY in range(tileY1, tileY2 + 1):
# ---> 79                 retrieve_sucess, horizontal_image = self.horizontal_retrieval_and_stitch_image(tileX1, tileX2, tileY, levl)
#      80                 if not retrieve_sucess:
#      81                     break
#
# ~\0_seawarden\python\detection\aerialImageRetrieval_2.py in horizontal_retrieval_and_stitch_image(self, tileX_start, tileX_end, tileY, level)
#     101         for tileX in range(tileX_start, tileX_end + 1):
#     102             quadkey = TileSystem.tileXY_to_quadkey(tileX, tileY, level)
# --> 103             image = self.download_image(quadkey)
#     104             if self.is_valid_image(image):
#     105                 imagelist.append(image)
#
# ~\0_seawarden\python\detection\aerialImageRetrieval_2.py in download_image(self, quadkey)
#      31
#      32     def download_image(self, quadkey):
# ---> 33         with request.urlopen(BASEURL.format(quadkey)) as file:
#      34             return Image.open(file)
#      35
#
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\envs\thesis\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
#add farm ID to filename (quick fix)
#import os 

#folder = "/Users/Zack/0_thesis_bing/images_2019-10-13/"
files = os.listdir(folder)
#print(files)

#sort files by date: newest to oldest
search_dir = folder
os.chdir(search_dir)
files = filter(os.path.isfile, os.listdir(search_dir))
files = [os.path.join(f) for f in files] 
files.sort(key=lambda x: os.path.getmtime(x))
print(len(files))

#rename with farm ID
for index, i in enumerate(files):
    org = (i[11:])
    name = (str(index))
    dst = (name + org)
    src = (i)
    os.rename(src, dst)
