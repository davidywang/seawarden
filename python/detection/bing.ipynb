# %%
#aerialImageRetrieval commandline in python
# %run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076

# %%
#load csv containing coordinates of polygon corners
import pandas as pd

#file = '/Users/Zack/0_thesis_bing/aquaculture_targets.csv'
#file = '/Users/Zack/Desktop/sar_targets.csv'
file = '/Users/Zack/Desktop/test.csv'
targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))
targets.head()

topleft = targets.drop(targets.index[0])
topleft = topleft.iloc[::5]
print(len(topleft))
topleft.head()

bright = targets.drop(targets.index[0:3])
bright = bright.iloc[::5]
print(len(bright))
bright.head()
# Out:
# 6830
# 1366
# 1366
#             x          y  id
# 3   24.058198  34.872170   0
# 8   24.056301  34.876726   1
# 13  24.069966  34.877628   2
# 18  25.729782  34.879741   3
# 23  25.720129  34.886167   4

# %%
#single location extractor
from aerialImageRetrieval_2 import AerialImageRetrieval
x=239
lat1=topleft['y'].tolist()[x]
lon1=topleft['x'].tolist()[x]
lat2=bright['y'].tolist()[x]
lon2=bright['x'].tolist()[x]

print(topleft['y'].tolist()[x])
print(topleft['x'].tolist()[x])
print(bright['y'].tolist()[x])
print(bright['x'].tolist()[x])

imgretrieval = AerialImageRetrieval(lat1, lon1, lat2, lon2)
if imgretrieval.max_resolution_imagery_retrieval():
    print("Successfully retrieved the image with maximum resolution!")
else:
    print("Cannot retrieve the desired image! (Possible reason: expected tile image does not exist.)")
# Out:
# 36.629436704599634
# 27.813902789067267
# 36.638788975111844
# 27.80318530502795
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# Successfully retrieved the image with maximum resolution!

# %%
# create lists
lat1_list=topleft['y'].tolist()
lon1_list=topleft['x'].tolist()
lat2_list=bright['y'].tolist()
lon2_list=bright['x'].tolist()
from aerialImageRetrieval_2 import AerialImageRetrieval

for i in range(len(lat1_list)):
    lat1=round(lat1_list[i],4)
    lon1=round(lon1_list[i],4)
    lat2=round(lat2_list[i],4)
    lon2=round(lon2_list[i],4)
    print(lat1, lon1, lat2, lon2)
    
    imgretrieval = AerialImageRetrieval(lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print(lat1, lon1, lat2, lon2, "Successfully retrieved the image with maximum resolution!")
    else:
        print(lat1, lon1, lat2, lon2, "Cannot retrieve the desired image! (Possible reason: expected tile image does not exist.)")
# Out:
# 34.8631 24.0691 34.8722 24.0582
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.8631 24.0691 34.8722 24.0582 Successfully retrieved the image with maximum resolution!
# 34.8677 24.0672 34.8767 24.0563
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.8677 24.0672 34.8767 24.0563 Successfully retrieved the image with maximum resolution!
# 34.8686 24.0809 34.8776 24.07
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.8686 24.0809 34.8776 24.07 Successfully retrieved the image with maximum resolution!
# 34.8706 25.7405 34.8797 25.7298
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.8706 25.7405 34.8797 25.7298 Successfully retrieved the image with maximum resolution!
# 34.877 25.7309 34.8862 25.7201
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.877 25.7309 34.8862 25.7201 Successfully retrieved the image with maximum resolution!
# 34.9228 24.9069 34.9319 24.896
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9228 24.9069 34.9319 24.896 Successfully retrieved the image with maximum resolution!
# 34.9349 23.9944 34.9439 23.9835
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9349 23.9944 34.9439 23.9835 Successfully retrieved the image with maximum resolution!
# 34.9248 26.1521 34.934 26.1414
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9248 26.1521 34.934 26.1414 Successfully retrieved the image with maximum resolution!
# 34.9402 26.1598 34.9494 26.1491
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9402 26.1598 34.9494 26.1491 Successfully retrieved the image with maximum resolution!
# 34.9667 24.7535 34.9758 24.7427
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9667 24.7535 34.9758 24.7427 Successfully retrieved the image with maximum resolution!
# 34.9638 25.6741 34.973 25.6633
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9638 25.6741 34.973 25.6633 Successfully retrieved the image with maximum resolution!
# 34.9599 26.1385 34.9691 26.1278
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9599 26.1385 34.9691 26.1278 Successfully retrieved the image with maximum resolution!
# 34.9528 25.2468 34.9619 25.236
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9528 25.2468 34.9619 25.236 Successfully retrieved the image with maximum resolution!
# 34.9568 25.2614 34.9659 25.2506
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9568 25.2614 34.9659 25.2506 Successfully retrieved the image with maximum resolution!
# 34.9285 24.8158 34.9376 24.805
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9285 24.8158 34.9376 24.805 Successfully retrieved the image with maximum resolution!
# 34.9279 24.9857 34.937 24.9748
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.9279 24.9857 34.937 24.9748 Successfully retrieved the image with maximum resolution!
# 34.988 26.1158 34.9972 26.1051
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 34.988 26.1158 34.9972 26.1051 Successfully retrieved the image with maximum resolution!
# 35.0004 26.1516 35.0096 26.1409
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.0004 26.1516 35.0096 26.1409 Successfully retrieved the image with maximum resolution!
# 35.0488 24.7344 35.0579 24.7235
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.0488 24.7344 35.0579 24.7235 Successfully retrieved the image with maximum resolution!
# 35.0762 24.7423 35.0853 24.7314
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.0762 24.7423 35.0853 24.7314 Successfully retrieved the image with maximum resolution!
# 35.1578 24.1045 35.1669 24.0936
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1578 24.1045 35.1669 24.0936 Successfully retrieved the image with maximum resolution!
# 35.1624 24.4244 35.1715 24.4135
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1624 24.4244 35.1715 24.4135 Successfully retrieved the image with maximum resolution!
# 35.168 24.3972 35.1771 24.3863
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.168 24.3972 35.1771 24.3863 Successfully retrieved the image with maximum resolution!
# 35.1734 24.2409 35.1825 24.23
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1734 24.2409 35.1825 24.23 Successfully retrieved the image with maximum resolution!
# 35.1813 24.3674 35.1903 24.3564
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1813 24.3674 35.1903 24.3564 Successfully retrieved the image with maximum resolution!
# 35.1828 25.9586 35.192 25.9478
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1828 25.9586 35.192 25.9478 Successfully retrieved the image with maximum resolution!
# 35.189 25.9621 35.1982 25.9513
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.189 25.9621 35.1982 25.9513 Successfully retrieved the image with maximum resolution!
# 35.1815 25.858 35.1907 25.8472
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1815 25.858 35.1907 25.8472 Successfully retrieved the image with maximum resolution!
# 35.1886 25.726 35.1978 25.7152
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1886 25.726 35.1978 25.7152 Successfully retrieved the image with maximum resolution!
# 35.1938 25.9655 35.203 25.9547
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1938 25.9655 35.203 25.9547 Successfully retrieved the image with maximum resolution!
# 35.1999 25.7276 35.2091 25.7168
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.1999 25.7276 35.2091 25.7168 Successfully retrieved the image with maximum resolution!
# 35.2038 26.1152 35.213 26.1045
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2038 26.1152 35.213 26.1045 Successfully retrieved the image with maximum resolution!
# 35.2291 23.6001 35.238 23.5891
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2291 23.6001 35.238 23.5891 Successfully retrieved the image with maximum resolution!
# 35.2189 23.6801 35.2279 23.6691
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2189 23.6801 35.2279 23.6691 Successfully retrieved the image with maximum resolution!
# 35.2372 26.1271 35.2465 26.1163
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2372 26.1271 35.2465 26.1163 Successfully retrieved the image with maximum resolution!
# 35.2402 26.0925 35.2494 26.0818
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2402 26.0925 35.2494 26.0818 Successfully retrieved the image with maximum resolution!
# 35.264 23.5251 35.273 23.514
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.264 23.5251 35.273 23.514 Successfully retrieved the image with maximum resolution!
# 35.259 23.5475 35.2679 23.5364
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.259 23.5475 35.2679 23.5364 Successfully retrieved the image with maximum resolution!
# 35.2695 26.2363 35.2788 26.2256
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2695 26.2363 35.2788 26.2256 Successfully retrieved the image with maximum resolution!
# 35.2888 26.2733 35.298 26.2626
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2888 26.2733 35.298 26.2626 Successfully retrieved the image with maximum resolution!
# 35.296 26.2676 35.3053 26.2568
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.296 26.2676 35.3053 26.2568 Successfully retrieved the image with maximum resolution!
# 35.3 23.5179 35.309 23.5068
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3 23.5179 35.309 23.5068 Successfully retrieved the image with maximum resolution!
# 35.293 25.4732 35.3022 25.4624
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.293 25.4732 35.3022 25.4624 Successfully retrieved the image with maximum resolution!
# 35.3141 26.3061 35.3233 26.2954
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3141 26.3061 35.3233 26.2954 Successfully retrieved the image with maximum resolution!
# 35.3209 26.16 35.3301 26.1492
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3209 26.16 35.3301 26.1492 Successfully retrieved the image with maximum resolution!
# 35.344 25.0521 35.3531 25.0412
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.344 25.0521 35.3531 25.0412 Successfully retrieved the image with maximum resolution!
# 35.3393 26.1742 35.3486 26.1634
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3393 26.1742 35.3486 26.1634 Successfully retrieved the image with maximum resolution!
# 35.3111 26.2927 35.3203 26.282
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3111 26.2927 35.3203 26.282 Successfully retrieved the image with maximum resolution!
# 35.3345 23.5343 35.3435 23.5232
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3345 23.5343 35.3435 23.5232 Successfully retrieved the image with maximum resolution!
# 35.2517 26.2266 35.2609 26.2158
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2517 26.2266 35.2609 26.2158 Successfully retrieved the image with maximum resolution!
# 35.2606 25.7288 35.2698 25.718
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.2606 25.7288 35.2698 25.718 Successfully retrieved the image with maximum resolution!
# 35.261 25.7428 35.2702 25.732
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.261 25.7428 35.2702 25.732 Successfully retrieved the image with maximum resolution!
# 35.3689 24.4872 35.378 24.4762
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3689 24.4872 35.378 24.4762 Successfully retrieved the image with maximum resolution!
# 35.3355 26.8863 35.3448 26.8756
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3355 26.8863 35.3448 26.8756 Successfully retrieved the image with maximum resolution!
# 35.3423 26.8632 35.3516 26.8525
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3423 26.8632 35.3516 26.8525 Successfully retrieved the image with maximum resolution!
# 35.3689 26.1753 35.3781 26.1645
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3689 26.1753 35.3781 26.1645 Successfully retrieved the image with maximum resolution!
# 35.355 26.8458 35.3643 26.8351
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.355 26.8458 35.3643 26.8351 Successfully retrieved the image with maximum resolution!
# 35.3626 26.8535 35.3719 26.8428
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3626 26.8535 35.3719 26.8428 Successfully retrieved the image with maximum resolution!
# 35.4036 24.437 35.4127 24.426
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4036 24.437 35.4127 24.426 Successfully retrieved the image with maximum resolution!
# 35.4024 24.5046 35.4115 24.4937
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4024 24.5046 35.4115 24.4937 Successfully retrieved the image with maximum resolution!
# 35.4033 24.5666 35.4123 24.5556
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4033 24.5666 35.4123 24.5556 Successfully retrieved the image with maximum resolution!
# 35.4044 24.5288 35.4135 24.5178
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4044 24.5288 35.4135 24.5178 Successfully retrieved the image with maximum resolution!
# 35.4169 24.7888 35.426 24.7779
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4169 24.7888 35.426 24.7779 Successfully retrieved the image with maximum resolution!
# 35.3963 27.1382 35.4056 27.1275
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.3963 27.1382 35.4056 27.1275 Successfully retrieved the image with maximum resolution!
# 35.438 24.7827 35.4471 24.7718
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.438 24.7827 35.4471 24.7718 Successfully retrieved the image with maximum resolution!
# 35.4164 26.9291 35.4256 26.9184
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4164 26.9291 35.4256 26.9184 Successfully retrieved the image with maximum resolution!
# 35.4354 25.2116 35.4445 25.2007
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4354 25.2116 35.4445 25.2007 Successfully retrieved the image with maximum resolution!
# 35.4598 24.7404 35.4689 24.7295
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4598 24.7404 35.4689 24.7295 Successfully retrieved the image with maximum resolution!
# 35.4223 27.1778 35.4316 27.1671
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 35.4223 27.1778 35.4316 27.1671 Successfully retrieved the image with maximum resolution!
# 35.4236 26.8606 35.4328 26.8499
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# ...
# 40.9256 24.9759 40.9347 24.9642 Successfully retrieved the image with maximum resolution!
# 40.9282 24.5307 40.9372 24.5189
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.9282 24.5307 40.9372 24.5189 Successfully retrieved the image with maximum resolution!
# 40.9938 25.1696 41.003 25.1579
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.9938 25.1696 41.003 25.1579 Successfully retrieved the image with maximum resolution!
# 41.0562 25.1219 41.0653 25.1102
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 41.0562 25.1219 41.0653 25.1102 Successfully retrieved the image with maximum resolution!
# 41.0571 25.1279 41.0663 25.1162
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 41.0571 25.1279 41.0663 25.1162 Successfully retrieved the image with maximum resolution!
# 40.992 25.1274 41.0011 25.1157
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.992 25.1274 41.0011 25.1157 Successfully retrieved the image with maximum resolution!
# 40.9242 24.5763 40.9333 24.5645
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.9242 24.5763 40.9333 24.5645 Successfully retrieved the image with maximum resolution!
# 40.9261 24.4137 40.9352 24.4018
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.9261 24.4137 40.9352 24.4018 Successfully retrieved the image with maximum resolution!
# 40.5452 22.7512 40.5541 22.7392
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5452 22.7512 40.5541 22.7392 Successfully retrieved the image with maximum resolution!
# 40.5448 22.8312 40.5537 22.8193
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5448 22.8312 40.5537 22.8193 Successfully retrieved the image with maximum resolution!
# 40.5474 22.7733 40.5563 22.7614
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5474 22.7733 40.5563 22.7614 Successfully retrieved the image with maximum resolution!
# 40.5532 24.633 40.5623 24.6212
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5532 24.633 40.5623 24.6212 Successfully retrieved the image with maximum resolution!
# 40.5491 22.8775 40.5579 22.8656
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5491 22.8775 40.5579 22.8656 Successfully retrieved the image with maximum resolution!
# 40.55 22.845 40.5588 22.8331
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.55 22.845 40.5588 22.8331 Successfully retrieved the image with maximum resolution!
# 40.5513 22.8153 40.5602 22.8033
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5513 22.8153 40.5602 22.8033 Successfully retrieved the image with maximum resolution!
# 40.5139 22.7554 40.5228 22.7435
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5139 22.7554 40.5228 22.7435 Successfully retrieved the image with maximum resolution!
# 40.5073 22.7026 40.5161 22.6906
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5073 22.7026 40.5161 22.6906 Successfully retrieved the image with maximum resolution!
# 40.5039 22.6734 40.5128 22.6615
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5039 22.6734 40.5128 22.6615 Successfully retrieved the image with maximum resolution!
# 40.506 22.7429 40.5149 22.7309
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.506 22.7429 40.5149 22.7309 Successfully retrieved the image with maximum resolution!
# 40.5193 22.9479 40.5282 22.9359
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 40.5193 22.9479 40.5282 22.9359 Successfully retrieved the image with maximum resolution!
# 38.2579 20.3724 38.2665 20.3606
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 38.2579 20.3724 38.2665 20.3606 Successfully retrieved the image with maximum resolution!
# 38.3162 24.0949 38.3252 24.0835
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 38.3162 24.0949 38.3252 24.0835 Successfully retrieved the image with maximum resolution!
# 38.3165 24.0489 38.3255 24.0375
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 38.3165 24.0489 38.3255 24.0375 Successfully retrieved the image with maximum resolution!
# 38.2624 20.3809 38.271 20.369
# Current level 23 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 22 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 21 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 20 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Finish the aerial image retrieval, store the image aerialImage_18.jpeg in folder /Users/Zack/0_thesis_bing
# 38.2624 20.3809 38.271 20.369 Successfully retrieved the image with maximum resolution!

# %%
#add farm ID to filename (quick fix)
#import os 

#folder = "/Users/Zack/0_thesis_bing/images_2019-10-13/"
files = os.listdir(folder)
#print(files)

#sort files by date: newest to oldest
search_dir = folder
os.chdir(search_dir)
files = filter(os.path.isfile, os.listdir(search_dir))
files = [os.path.join(f) for f in files] 
files.sort(key=lambda x: os.path.getmtime(x))
print(len(files))

#rename with farm ID
for index, i in enumerate(files):
    org = (i[11:])
    name = (str(index))
    dst = (name + org)
    src = (i)
    os.rename(src, dst)
# Out:
# 252
