# %%
#aerialImageRetrieval commandline in python
#%run -i ../0_thesis_bing/Satellite-Aerial-Image-Retrieval-master/aerialImageRetrieval_2.py 41.882981 -87.623496 41.882397 -87.623076

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping
from aerialImageRetrieval import AerialImageRetrieval

#load csv containing coordinates of polygon corners
f = '/Users/Zack/0_seawarden/python/detection_prep/targets_sar/'
file = f + '2019_g25_100m_10-20_1yr_02-01.csv'

#load centroids to include in filename
centroids = gpd.read_file(f + '2019_g25_100m_10-20_1yr_02-01.geojson')

targets = pd.read_csv(file, delimiter=',', header=0)
print(len(targets))

tl = targets.drop(targets.index[0])
tl = tl.iloc[::5]
print(len(tl))

br = targets.drop(targets.index[0:3])
br = br.iloc[::5] 
print(len(br))

# create lists
lat1_list=tl['y'].tolist()
lon1_list=tl['x'].tolist()
lat2_list=br['y'].tolist()
lon2_list=br['x'].tolist()

for i in range(3280,3395):
    lat1=round(lat1_list[i],5)
    lon1=round(lon1_list[i],5)
    lat2=round(lat2_list[i],5)
    lon2=round(lon2_list[i],5)
    
    xy = mapping(centroids.geometry[i])['coordinates']
    x = round(xy[0], 5)
    y = round(xy[1], 5)

    imgretrieval = AerialImageRetrieval(x, y, lat1, lon1, lat2, lon2)
    if imgretrieval.max_resolution_imagery_retrieval():
        print("Retrieved image:", lat1, lon1, lat2, lon2)
    else:
        print("Cannot retrieve image:", lat1, lon1, lat2, lon2)
# Out:
# 16965
# 3393
# 3393
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.77554 26.05646 40.78475 26.0449
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.77564 26.05769 40.78485 26.04612
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.7995 25.72792 40.80868 25.71631
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.79872 25.83057 40.80791 25.81897
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.79629 26.00897 40.8055 25.99739
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.802 26.00556 40.81121 25.99398
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.80297 26.00461 40.81218 25.99303
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.80973 26.01259 40.81894 26.00101
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.8324 24.3158 40.84144 24.30398
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.81853 25.88615 40.82773 25.87455
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.84193 24.80182 40.85102 24.79007
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.84505 24.3254 40.85409 24.31358
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.83253 25.89525 40.84173 25.88365
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.84666 24.79106 40.85575 24.7793
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.83566 25.9097 40.84485 25.89811
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.83493 25.95746 40.84413 25.94587
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.83637 25.90825 40.84557 25.89665
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.8372 25.90915 40.84639 25.89756
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.85311 24.70706 40.86219 24.69529
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.84207 25.75613 40.85126 25.74451
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.84193 25.92103 40.85113 25.90943
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.85789 24.64169 40.86697 24.62991
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.86296 24.3242 40.872 24.31238
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.85363 25.55652 40.86279 25.54487
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.86728 24.63109 40.87636 24.61931
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87321 24.39038 40.88225 24.37857
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87594 24.63301 40.88501 24.62122
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87623 24.62916 40.8853 24.61737
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87808 24.62967 40.88715 24.61789
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87044 25.51268 40.8796 25.50102
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87874 24.62607 40.88781 24.61428
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87262 25.44065 40.88177 25.42898
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.87208 25.51383 40.88124 25.50217
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.88377 24.62061 40.89284 24.60882
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.89155 24.6089 40.90062 24.59711
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.89748 24.60243 40.90655 24.59064
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.89783 24.60383 40.90689 24.59204
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.90213 24.5956 40.9112 24.58381
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.90239 24.59423 40.91145 24.58244
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91001 24.39017 40.91906 24.37835
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91228 24.59503 40.92135 24.58323
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.9163 24.58233 40.92537 24.57053
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91651 24.58244 40.92557 24.57064
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91103 25.27831 40.92016 25.26661
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91172 25.38259 40.92087 25.37091
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91266 25.38134 40.92181 25.36965
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.90579 24.59652 40.91486 24.58473
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.90591 24.59861 40.91498 24.58682
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.92026 24.57919 40.92933 24.56739
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.91363 25.37954 40.92278 25.36786
# *Current level 19 results an image exceeding the maximum image size (8192 * 8192), will SKIP
# Retrieved image: 40.